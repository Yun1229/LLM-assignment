# %%
from pytrials.client import ClinicalTrials
import pymongo
from pymongo import UpdateOne, InsertOne
import json
import pickle
import re
from openai import OpenAI
from config import api_key

# %%
#### Load the variables for reproducibility
with open("retrieved_studies.pkl", "rb") as f:
    retrieved_studies = pickle.load(f)

with open("mapped_data_all.pkl", "rb") as f:
    mapped_data_all = pickle.load(f)

# %% [markdown]
# ## Connect to local MongoDB
# create database and collection

# %%
client = pymongo.MongoClient("mongodb://localhost:27017/")

# %%
db = client["ClinicalTrialsDB"]

# %%
final_collection = db["clinical_trial_collection"]

# %%
# specify the json schema for database validation.

schema = {
    "type": "object",
    "additionalProperties": True,
    "properties": {
        "trialId": {
            "type": "string",
            "description": "A unique identifier for the clinical trial.",
        },
        "title": {
            "type": "string",
            "description": "The official title of the clinical trial.",
        },
        "startDate": {
            "type": "string",
            "pattern": "^^\\d{4}-\\d{2}-\\d{2}|NA$",
            "description": "The start date of the clinical trial.",
        },
        "endDate": {
            "type": "string",
            "pattern": "^^\\d{4}-\\d{2}-\\d{2}|NA$",
            "description": "The end date of the clinical trial, if applicable.",
        },
        "phase": {
            "type": "string",
            "enum": ["Phase 1", "Phase 2", "Phase 3", "Phase 4", "Other"],
            "description": "The phase of the clinical trial.",
        },
        "principalInvestigator": {
            "type": "array",
            "properties": {
                "name": {
                    "type": "string",
                    "description": "The name of the principal investigator.",
                },
                "affiliation": {
                    "type": "string",
                    "description": "The affiliation of the principal investigator.",
                },
            },
            "required": ["name"],
        },
        "locations": {
            "type": "array",
            "items": {
                "type": "object",
                "properties": {
                    "facility": {
                        "type": "string",
                        "description": "Name of the facility where the trial is conducted.",
                    },
                    "city": {
                        "type": "string",
                        "description": "The city where the facility is located.",
                    },
                    "country": {
                        "type": "string",
                        "description": "The country where the facility is located.",
                    },
                },
            },
        },
        "eligibilityCriteria": {
            "type": "string",
            "description": "A description of the eligibility criteria for the trial.",
        },
    },
    "required": ["trialId", "title", "phase"],
}

# %%
# Database validation.
db.create_collection(
    "clinical_trial_collection",
    validator={"$jsonSchema": schema},
    validationAction="warn",
)
# Out:
# Collection(Database(MongoClient(host=['localhost:27017'], document_class=dict, tz_aware=False, connect=True), 'ClinicalTrialsDB'), 'clinical_trial_collection')

# %%
client.list_database_names()
# Out:
# ['ClinicalTrialsDB', 'TestDB', 'admin', 'config', 'local']

# %%
db.list_collection_names()
# Out:
# ['clinical_trial_collection_updated', 'clinical_trial_collection']

# %% [markdown]
# ## Retrive metadata via clinicaltrials.gov API

# %%
ct = ClinicalTrials()

# %%
retrieved_studies = ct.get_full_studies(
    search_expr="AREA[LastUpdatePostDate]RANGE[2024-10-20, 2024-10-21]",
    max_studies=1000,  # more than 1000?
    fmt="json",
)

# %%
# Check how many studies are retrieved
len(retrieved_studies["studies"])
# Out:
# 619

# %%
def flatten(arg):
    if not isinstance(arg, list):  # if not list
        return [arg]
    return [x for sub in arg for x in flatten(sub)]

# %%
def get_nested_value(data, keys2):
    keys = keys2.split(".")
    for key in keys:
        if isinstance(data, dict):
            data = data.get(key)
        elif isinstance(data, list):
            valuelist = []
            for ele in data:
                valuelist.append(ele.get(key))
            data = flatten(valuelist)
    return data

# %% [markdown]
# ##### Functions for data mapping

# %%
def get_date(study):
    start = get_nested_value(study, "protocolSection.statusModule.startDateStruct.date")

    end = get_nested_value(
        study, "protocolSection.statusModule.completionDateStruct.date"
    )

    def modify_date(date):
        if date is None:
            return "NA"
        if len(date) == 7:
            return date + "-01"
        else:
            return date

    return modify_date(start), modify_date(end)

# %%
def get_phase(study):
    phase = get_nested_value(study, "protocolSection.designModule.phases")

    if phase == None:
        return "Other"
    return next(
        (
            f"Phase {p[-1]}"
            for p in phase
            if p.upper() in ["PHASE1", "PHASE2", "PHASE3", "PHASE4"]
        ),
        "Other",
    )

# %%
def get_principal_investigator(study):
    overall_officials = get_nested_value(
        study, "protocolSection.contactsLocationsModule.overallOfficials"
    )
    if not overall_officials:  # Check if overall_officials is None or empty
        return []

    return [
        {
            "name": official.get("name", "NA"),
            "affiliation": official.get("affiliation", "NA"),
        }
        for official in overall_officials
        if official.get("role") == "PRINCIPAL_INVESTIGATOR"
    ]

# %%
def get_locations(study):
    locations = get_nested_value(
        study, "protocolSection.contactsLocationsModule.locations"
    )

    if not locations:  # Check if overall_officials is None or empty
        return []
    return [
        {
            "facility": loc.get("facility", ""),
            "city": loc.get("city", ""),
            "country": loc.get("country", ""),
        }
        for loc in locations
    ]

# %%
def transform_study(study):

    return {
        "trialId": get_nested_value(
            study, "protocolSection.identificationModule.nctId"
        ),
        "title": get_nested_value(
            study, "protocolSection.identificationModule.officialTitle"
        ),
        "startDate": get_date(study)[0],
        "endDate": get_date(study)[1],
        "phase": get_phase(study),
        "principalInvestigator": get_principal_investigator(study),
        "locations": get_locations(study),
        "eligibilityCriteria": get_nested_value(
            study, "protocolSection.eligibilityModule.eligibilityCriteria"
        ),
    }

# %%
def map_data(input_data):
    transformed_data = []
    for study in input_data["studies"]:
        transformed_data.append(transform_study(study))
    return transformed_data

# %%
# Transform the input data
mapped_data_all = map_data(retrieved_studies)

# %%
# Sanity check: if all studies are mapped
len(retrieved_studies["studies"]) == len(mapped_data_all)
# Out:
# True

# %%
#### Save the variables for reproducibility

# with open("retrieved_studies.pkl", "wb") as f:


#     pickle.dump(retrieved_studies, f)


# with open("mapped_data_all.pkl", "wb") as f:


#     pickle.dump(mapped_data_all, f)

# %%
# Function to insert or update data in MongoDB
def upsert_data_to_db(data, collection):
    requests = []

    # Fetch original documents before updating
    for entry in data:
        trial_id = entry["trialId"]
        original_document = collection.find_one({"trialId": trial_id})
        if original_document:
            requests.append(
                UpdateOne({"trialId": trial_id}, {"$set": entry})
            )  # upsert=False
            for key, value in entry.items():
                old_value = original_document.get(key)
                if old_value != value:  # Identify modified fields
                    print(
                        f"Trial ID: {trial_id}, Field: {key}, From: {old_value} To: {value}"
                    )
        else:
            requests.append(InsertOne(entry))

    if requests:
        result = collection.bulk_write(requests)  # Use bulk_write for batch processing
        if result.inserted_count > 0:
            print(f"Number of documents inserted: {result.inserted_count}")

        if result.modified_count > 0:
            print(f"Number of documents updated: {result.modified_count}")

    collection.create_index("trialId")

# %%
upsert_data_to_db(mapped_data_all, final_collection)
# Out:
# Number of documents inserted: 619

# %%
# Sanity check: if all studies are inserted
len(retrieved_studies["studies"]) == len(
    mapped_data_all
) == final_collection.count_documents({}) == 619
# Out:
# True

# %%
# Sanity check
mapped_data_all[10]
# Out:
# {'trialId': 'NCT06649591',
#  'title': 'A Survey Based Study Assessing the Feasibility of Using Standardized Clinical Vignettes to Aid in Medical Decision in Patients with Malignant Brain Tumors',
#  'startDate': '2017-07-01',
#  'endDate': '2025-12-01',
#  'phase': 'Other',
#  'principalInvestigator': [{'name': 'Marie Roguski, MD MPH',
#    'affiliation': 'Tufts Medical Center'}],
#  'locations': [{'facility': 'Tufts Medical Center',
#    'city': 'Boston',
#    'country': 'United States'}],
#  'eligibilityCriteria': 'Inclusion Criteria:\r\n\r\n  -  consecutive patients treated at a single center between April 2018 and July 2023 for\r\n     malignant brain tumors, including glioma, metastasis, and lymphoma.\r\n\r\nExclusion Criteria:\r\n\r\n  -  Patients without available MRI dicom images\r\n\r\n  -  Patients with other CNS malignancies\r\n\r\n  -  Patients with multiply recurrent gliomas undergoing treatment for primarily\r\n     palliative purposes\r\n\r\n  -  Patients younger than 18 years old',
#  '_id': ObjectId('673285464dd83486d5a4d343')}

# %%
# Sanity check
mapped_data_all[15]
# Out:
# {'trialId': 'NCT04431960',
#  'title': 'Blackcurrant Modifies Gut Microbiota and Reduces the Risk of Postmenopausal Osteoporosis and Cardiovascular Disease: A Pilot Randomized Clinical Trial',
#  'startDate': '2021-07-20',
#  'endDate': '2022-10-03',
#  'phase': 'Phase 1',
#  'principalInvestigator': [{'name': 'Ock K Chun, PhD',
#    'affiliation': 'University of Connecticut'}],
#  'locations': [{'facility': 'University of Connecticut Department of Nutritional Sciences and Kinesiology Human Performance Laboratory',
#    'city': 'Storrs',
#    'country': 'United States'}],
#  'eligibilityCriteria': 'Inclusion Criteria:\r\n\r\n  -  perimenopausal or early postmenopausal women aged 45-60 years old\r\n\r\n  -  not on HRT for at least one year before the initiation of the study\r\n\r\n  -  maintaining normal exercise level (<7 h/wk) and willing to avoid exercise 24-h prior\r\n     to blood and stool sampling and 12-h prior to bone measurements\r\n\r\n  -  willing to ingest a dietary BC supplement or placebo (up to 900 mg/day, two 450 mg\r\n     capsules) as well as 400 mg calcium and 500 IU vitamin D daily\r\n\r\n  -  willing to avoid other dietary supplements for the duration of the study\r\n\r\n  -  willing to avoid intake of foods extremely rich in anthocyanins and fermented dairy\r\n     products containing viable Bifidobacteria or Lactobacilli\r\n\r\n  -  willing to have 3 blood draws, 2 stool collections, and 2 bone scans\r\n\r\n  -  willing to take urine pregnancy test if they are perimenopausal.\r\n\r\nExclusion Criteria:\r\n\r\n  -  those with metabolic bone disease, renal disease, cancer, cardiovascular disease,\r\n     diabetes mellitus, respiratory disease, gastrointestinal disease, liver disease or\r\n     other chronic diseases\r\n\r\n  -  those with hypertension or on drugs that lower blood pressure\r\n\r\n  -  those with planned surgery during the study period or within 2 weeks of ending the\r\n     intervention\r\n\r\n  -  taking medications that alter bleeding (such as antiplatelets or anticoagulants) or\r\n     those with a bleeding disorder\r\n\r\n  -  taking a phenothiazine drug (most commonly used for nausea or mental health\r\n     conditions)\r\n\r\n  -  having a sensitivity or allergy to any of ingredients for the placebo (rice powder)\r\n     and calcium/D supplement (calcium citrate, polyethylene glycol, croscarmellose\r\n     sodium, hydroxypropyl methylcellulose, magnesium stearate, oligofructose enriched\r\n     inulin, propylene glycol dicaprylate/dicaprate, talc, titanium dioxide, vitamin D3)\r\n\r\n  -  heavy smokers (>20 cigarettes/day)\r\n\r\n  -  perimenopausal women with any chance or plan of pregnancy\r\n\r\n  -  taking prescription medications known to alter bone and Ca metabolism such as\r\n     calcitonin, bisphosphonates, raloxifene within 3 months before the start of the\r\n     study\r\n\r\n  -  taking anabolic agents such as parathyroid hormone, growth hormone, or steroids\r\n     within 3 months before the start of the study\r\n\r\n  -  planning any procedure that includes iodine, barium or nuclear medicine isotopes in\r\n     next 7 months\r\n\r\n  -  alcohol consumption exceeding 2 drinks/day (approximately 14 g ethanol per drink) or\r\n     a total of 12/week\r\n\r\n  -  UConn students and/or employees who any key personnel teach or who report to any key\r\n     personnel\r\n\r\n  -  study key personnel, spouses of key personnel, or dependents/relatives of any key\r\n     personnel.',
#  '_id': ObjectId('673285464dd83486d5a4d348')}

# %% [markdown]
# Test if upsert_data_to_db suports data update:

# %%
updated_collection = db["clinical_trial_collection_updated"]
db.create_collection(
    "clinical_trial_collection_updated", validator={"$jsonSchema": schema}
)
# mapped_data_all = map_data(retrieved_studies)
upsert_data_to_db(mapped_data_all, updated_collection)
# Out:
# Number of documents inserted: 619

# %%
updated_studies = {"studies": []}
updated_trial = ["NCT06649721", "NCT05254002"]  # Randomly select trials to be updated


# Update trials with specified nctId values and store them in updated_studies
for study in retrieved_studies["studies"]:
    updated_ids = study["protocolSection"]["identificationModule"].get("nctId")
    if updated_ids in updated_trial:
        study_copy = copy.deepcopy(study)
        study_copy["protocolSection"]["statusModule"]["completionDateStruct"][
            "date"
        ] = "9999-99-99"  # update date
        study_copy["protocolSection"]["designModule"]["phases"] = [
            "PHASE9"
        ]  # update phase
        updated_studies["studies"].append(study_copy)


mapped_data_updated = map_data(updated_studies)
upsert_data_to_db(mapped_data_updated, updated_collection)
# Out:
# Number of documents updated: 2
# Trial ID: NCT05254002, Field: endDate, From: 2025-11-30 To: 9999-99-99
# Trial ID: NCT05254002, Field: phase, From: Phase 2 To: Other
# Trial ID: NCT06649721, Field: endDate, From: 2027-06-30 To: 9999-99-99
# Trial ID: NCT06649721, Field: phase, From: Phase 3 To: Other

# %% [markdown]
# #### Sanity checks for database

# %%
# Sanity check
p1 = final_collection.count_documents({"phase": "Phase 1"})


p2 = final_collection.count_documents({"phase": "Phase 2"})


p3 = final_collection.count_documents({"phase": "Phase 3"})


p4 = final_collection.count_documents({"phase": "Phase 4"})


o = final_collection.count_documents({"phase": "Other"})


print(p1, p2, p3, p4, o)


print(p1 + p2 + p3 + p4 + o)
# Out:
# 90 96 61 23 349
# 619

# %%
for trial in final_collection.find({"title": {"$regex": "Diabete", "$options": "i"}}):
    pprint.pprint(trial.get("trialId"))


final_collection.count_documents({"title": {"$regex": "Diabete", "$options": "i"}})
# Out:
# 'NCT06649773'
# 'NCT04745572'
# 'NCT06650969'
# 'NCT05910840'
# 'NCT05743244'
# 'NCT05963022'
# 'NCT04413357'
# 'NCT05026424'
# 'NCT03835312'
# 'NCT02806700'
# 'NCT04914559'
# 'NCT05254002'
# 'NCT06650007'
# 'NCT06579105'
# 14

# %%
for trial in final_collection.find({"title": {"$regex": "HER2", "$options": "i"}}):
    pprint.pprint(trial.get("trialId"))


final_collection.count_documents({"title": {"$regex": "HER2", "$options": "i"}})
# Out:
# 'NCT05945927'
# 'NCT04513665'
# 'NCT06065748'
# 'NCT03901339'
# 'NCT03280563'
# 'NCT03587740'
# 'NCT05425550'
# 'NCT02007512'
# 'NCT06364410'
# 'NCT06650332'
# 'NCT02297438'
# 11

# %%
final_collection.count_documents(
    {"startDate": {"$gte": "2020-01-01", "$lte": "2024-12-31"}}
)
# Out:
# 455

# %%
final_collection.count_documents(
    {
        "locations": {
            "$elemMatch": {
                "facility": {"$regex": "Orange County Research Center", "$options": "i"}
            }
        }
    }
)
# Out:
# 3

# %%
final_collection.count_documents(
    {"principalInvestigator": {"$elemMatch": {"name": "Marie Roguski, MD MPH"}}}
)
# Out:
# 1

# %%
# Get a distinct list of all principal investigator names
distinct_principal_investigators = final_collection.distinct(
    "principalInvestigator.name"
)

print("Distinct Principal Investigators:")
for name in distinct_principal_investigators:
    print(name)
# Out:
# Distinct Principal Investigators:
# Aaron Folsom, MD, MPH
# Aaron Shafer, MD
# Abdusalom Abdurakhmanov, MD
# Abraham Wu, MD
# Adeyemi Ogunleye, MD
# Afton Hassett
# Ajay Premkumar, MD
# Alain SAAD
# Alain SAAD, MD
# Alaine E Reschke-Hernandez, PhD
# Alaine E. Reschke-Hernandez, PhD
# Alethea Desrosiers
# Alexis MOSCA, MD
# Alice L Yu
# Allison Gibson, PhD
# Amanda Rao, PhD
# Ana Oaknin, MD
# Anders Thorell, Professor
# Andreas M Fritzen, Associate Professor
# Andreas Peyrl, MD
# Andreas Trojan, Prof. Dr. med.
# Andrew Kneebone
# Ann Smeets, MD,PhD
# Anna De Simoni, PhD
# Anna GEMAHLING, MD
# Anna H. Grummon, PhD
# Anna Maria Hibbs, MD, MSCE
# Anne-Sophie Brazeau, PhD
# Annette DeVito Dabbs, PhD
# Anxo Fernandez-Ferreiro, PhD
# Audrey Harkness, PhD
# Aung Naing, Md
# Boris Bogov, Prof, PhD
# Bouthaina S Dabaja
# Brian Helfand, M.D.
# Brian Vickery, MD
# CORALIE NOEL
# Carla S Stover, Ph.D.
# Carlos A Zarate, M.D.
# Carlos Chaccour
# Carolyn Bramante, MD
# Carrie L Pistenmaa, MD, MS
# Cavan Reilly, PhD
# Channing Paller, MD
# Chao-Chi Ho, MD, PhD
# Chaohui Yu, Doctor
# Chaosu Hu
# Charles Powell, DDS, MS
# Christian Castilla López, MsC
# Christoper Barker, MD
# Christopher J Melani
# Claudia Campbell, PhD
# Claudia Fox, MD, MPH
# Claus Cursiefen, Prof. Dr.
# Craig Crandall, PhD
# Crystal D Karakochuk, PhD
# Cédric LAMIREL, MD
# DINO TIKVESA, MD
# Dahui Wang, MD-PhD
# Damiano Rondelli, MD
# Damien GUINDOLET
# Daniel Jones, MBBS, PhD
# Danijela Trifunovic-Zamklar, MD, PhD
# David Darrow, MD
# David Kim, DDS, DMSc
# David Ostry
# David R Smith, Ph.D.
# Dawood Sayed, MD
# Deepa G Manwani, M.D
# Diwakar Davar, MD, M.Sc
# Dominique BREMOND-GIGNAC, MD
# Dongmei Ji
# Drew Sayer, PhD
# Dustin C Lee, PhD
# Ecaterina E Dumbrava
# Edelgard Lindhoff-Last, Professor
# Edward G Clark, MD MSc FRCPC
# Elias Jabbour
# Elizabeth Brem, MD
# Elizabeth McClure, PhD
# Emily A Kringle, PhD, OTR/L
# Emily G McDonald, MD MSC
# Emily G McDonald, MD MSc
# Eric GABISON, MD
# Erica C. Kaye, MD, MPH
# Erika Matos, PhD
# Etta Pisano
# Eugenio Fernandez
# Eva Szigethy
# Federico Linassi, MD
# Frank A Bucci, Jr., MD
# Frank A Bucci, MD
# Frederique Paulus, prof. dr.
# Funda Meric-Bernstam
# Gareth R Dutton, PhD
# Georgi Momekov, Prof PhD
# Ghazala Saleem, EdD
# Giorgia Sulis, PhD
# Giorgio Gastaldi, MD, DDS
# Graham Foster, MBBS
# Guido Beldi
# Guillaume Maquis-Gravel, MD,MSc
# Guliano Cerulli, MD
# Hamiyet Kızıl, Phd RN
# Hannah Linden
# Hans-Christoph Friederich, Prof. Dr.
# Heather Kaplan, MD, MSCE
# Helen Storr, PhD
# Helge Möllmann
# Henrik Grönberg, MD, PhD
# Hirva Mamdani, MD
# Holly Wyatt, MD
# Howard M Katzenstein
# Hrishikesh Chakraborty
# Ihsan Salloum, MD
# Imran K Niazi, MD
# Ismaël Conejero
# Ivan Wu
# J. Sven D. Mieog, MD PhD
# Jacques Izard, PhD
# James I Geller
# James Yu
# Jan Reidar Stiegler, PhD
# Jean L Rouleau, MD,PhD
# Jean-Philippe Drouin-Chartier, PhD
# Jeffrey M Jacobson
# Jeffrey R Wozniak, Ph.D.
# Jennifer Ellis, Ph.D.
# Jennifer Johansson, MS
# Jessica A Reese, PhD
# Jessica Ansari, MD, MS
# Jieer Ying, MD
# Jin H. Han, MD
# Jing Chen, PhD
# Jing Sun, MD, Ph.D
# JoAnna K Leyenaar, MD, PhD
# Johann Bauersachs, Prof. Dr.
# John A Sauceda, PhD
# John B. Liao
# John H Joseph, MD
# John Heinzerling, MD
# John Villano, MD, PhD
# Jonatan Ruiz Ruiz, Dr.
# Jonathan B. Bricker
# Julie Heimbach
# Justin Gregg, MD
# Karen Dzhambazov, Prof, PhD
# Kate V Meriwether, MD
# Kathryn Glaser
# Keith Choate, MD, PhD
# Kelli J England, PhD
# Kelsey M Cochrane, PhD
# Kenneth Offit, MD, MPH
# Kenneth W. Merrell, MD
# Kent Nilsson, MD
# Kerri Winters-Stone
# Kevin Hall, Ph.D.
# Kevin Knight, PhD
# Kevin Krull, PhD
# Kiminori Kimura, MD
# Krishan R. Jethwa, MD
# Kristen Kelley
# Kristen Lindgren, PhD, ABPP
# Kristie A Blum
# Kubra Alpay, PhD
# Lai Wei
# Lakshmi Koyyalagunta
# Lars O Cardell, Professor
# Laure Joseph, M.D.
# Laurie E Cutting, PhD
# Lead Investigator
# Leonard A Bradshaw, PhD
# Li Huo, MD
# Lily A Brown, PhD
# Liqun Jiao, MD
# Lisa S. Chow, MD
# Lora Giangregorio, PhD
# Lori J. Wirth, MD
# Lorne Tyrrell, MD PhD
# Lucas Boersma, Prof. MD.
# Luigi Ferrucci, M.D.
# Manali I Patel, MD MPH MS
# Margaret MacMillan
# Marianna Koczywas
# Marie Roguski, MD MPH
# Marina Caskey, MD
# Mario Gaudino, MD,PhD
# Marion Rabant, M.D., PhD
# Mark B Geyer, MD
# Mark Lazarev, MD
# Mark O'Hara, MD
# Marleen Kok, MD
# Martin K. Kankam, MD, PhD, MPH, FAPCR
# Martin Muckley, FRCPI
# Mary Billstrand, MD
# Maryam Fouladi, MD
# Massimo Volpe, Professor
# Matthew Tennant, MD, FRCSC
# Maura L Gillison
# Megan Gunnar, PhD
# Megan Marie Kelly, PhD MS
# Miae OH
# Michael Goggins, MD
# Michael Good, MD, PhD
# Michael Hawkes, MD, PhD
# Michael Houghton, PhD
# Michael Koenigs, PhD
# Michael R Harrison, MD
# Michele Bedard-Gilligan, PhD
# Michele Staton, MSW, PhD
# Michelle L Hermiston
# Milena Encheva, MD, PhD
# Milos Velinovic, MD, PhD
# Mohamed Hamdy, Lecturer
# Monali Vasekar, MD
# Motolani Adedipe, PhD, DPh, MS
# Muhammad Zarak Awais, MBBS
# Murielle Roussel, MD
# Nancy F Krebs, MD, MS
# Natalie Lockney, MD
# Nathan Congdon, MD
# Nicola Canessa, PhD
# Nicolas Palaskas, MD
# Nikolay Sapundziev, Prof, PhD
# Ock K Chun, PhD
# Olcay Aycicek, Asist Prof
# Pamela Samson, M.D., MPHS
# Paola Azucena Alvarado Pelayo, Bachelor
# Paolo F. Caimi, MD
# Patrick J Smith, PhD, MPH
# Paul Mulholland
# Peter Fasching, Prof. Dr. med.
# Peter Pellegrino, MD
# Pianosi Paolo, MD
# Pinghong Zhou, MD, PhD
# Principal Investigator
# Prof Andrew Prendergast, DPhil MRCPCH
# Puyu Su, Professor
# Qianyu Zhuang, Professor
# Rachel Freedman, MD MPH
# Ralph DeFronzo, MD
# Rebecca Sartini, DNP
# Regina Rabinovich
# Rena Jones, Ph.D.
# Reza Hejazi, MD
# Rianne Oosterkamp, MD
# Ricardo Espinoza, MD
# Rodabe N. Amaria, MD
# Rona Yaegar, MD
# Rosen Nikolov, Prof, MD
# Rumen Benchev, Prof
# Ruth Blanco Rojo, PhD
# Sacha NAHON ESTEVE
# Sara Ramel, MD
# Sarah Prinsloo
# Sarah Yip, PhD, MSc
# Saumil Gandhi, MD
# Savannah Partridge
# Sean M Oser, MD, MPH
# Sherman Holtan, MD
# Shira Goldenberg, PhD
# Shivaani Kummar, MD
# Shounak Majumder, M.D.
# Simon Wernhart, MD
# Sivasubramanium Bhavani, MD
# Sonja Merten, MD MPH PhD
# Sophie Susen, MD, Professor
# Spiridon Todorov, Prof, PhD
# Srivandana Akshintala
# Stefan Leucht, MD
# Stephanie Lheureux
# Stephen Fremes, MD,MSc,FRCSC
# Steven R Grossman, MD
# Stuart S Winter
# Sumit Gupta
# Summer Hanson, MD, PhD, FACS
# Surya P Bhatt, MD, MSPH
# Suzanne Wolden, MD
# Sümeyye Akçay, PT
# T. John Winhusen, PhD.
# TBD TBD
# Tamara K Oser, MD
# Terence T. Sio, MD, MS
# Thet Lynn, MD, MMedSc Global Health
# Thorsten Kahnt, Ph.D.
# Todd C Lee, MD MPH FIDSA
# Tokiko Hamasaki, PhD
# Trevor Duffy
# Ugur T. Sener, MD
# Vaishalee Kenkre, MD
# Valérie BENOIT
# Vanessa Meier-Stephenson, MD, PhD
# Vania Youroukova, Prof, PhD
# Vanphanom Sychareun, MD, PhD
# Vatinee Bunya, MD
# Veronkia Bachanova
# Vicky Makker, MD
# Vikky Makker, MD
# Ville Sallinen, MD, PhD
# Vladimir Hodzhev, Prof, PhD
# Werner Bischoff, MD
# William Gleason, OD
# Wilson Z Ray, MD
# Wolfgang Kemmler, PhD
# Xavier MOISSET
# Xiaojing Hu, PhD
# Xiaoli Nan
# Yan Ma, MD
# Yash B. Joshi, MD PhD
# Zeeshan Afzal, FCPS
# Zosia Piotrowska, MD
# rana ka Abuzaid, orthodontist

# %%
# Aggregation pipeline to count occurrences of each principal investigator name
pipeline = [
    {"$unwind": "$principalInvestigator"},
    {"$group": {"_id": "$principalInvestigator.name", "count": {"$sum": 1}}},
    {"$sort": {"count": -1}},  # Sort by count in descending order
]

# Run the aggregation pipeline
results = final_collection.aggregate(pipeline)

# Print the results
print("Number of documents for each Principal Investigator:")
for result in results:
    name = result["_id"]
    count = result["count"]
    print(f"{name}: {count}")
# Out:
# Number of documents for each Principal Investigator:
# Hrishikesh Chakraborty: 3
# Chaosu Hu: 2
# Dongmei Ji: 2
# Maryam Fouladi, MD: 2
# William Gleason, OD: 2
# Xiaojing Hu, PhD: 2
# Shounak Majumder, M.D.: 2
# Brian Helfand, M.D.: 1
# Lily A Brown, PhD: 1
# Daniel Jones, MBBS, PhD: 1
# Prof Andrew Prendergast, DPhil MRCPCH: 1
# Danijela Trifunovic-Zamklar, MD, PhD: 1
# Deepa G Manwani, M.D: 1
# Channing Paller, MD: 1
# Imran K Niazi, MD: 1
# Hamiyet Kızıl, Phd RN: 1
# Vikky Makker, MD: 1
# Vladimir Hodzhev, Prof, PhD: 1
# Shivaani Kummar, MD: 1
# Thorsten Kahnt, Ph.D.: 1
# Ann Smeets, MD,PhD: 1
# Kenneth Offit, MD, MPH: 1
# Marleen Kok, MD: 1
# Frank A Bucci, Jr., MD: 1
# Kevin Knight, PhD: 1
# Lars O Cardell, Professor: 1
# Georgi Momekov, Prof PhD: 1
# Terence T. Sio, MD, MS: 1
# Hirva Mamdani, MD: 1
# Drew Sayer, PhD: 1
# Lakshmi Koyyalagunta: 1
# Craig Crandall, PhD: 1
# James Yu: 1
# Paola Azucena Alvarado Pelayo, Bachelor: 1
# Li Huo, MD: 1
# Kristie A Blum: 1
# Ruth Blanco Rojo, PhD: 1
# Megan Gunnar, PhD: 1
# Mohamed Hamdy, Lecturer: 1
# Ricardo Espinoza, MD: 1
# Zosia Piotrowska, MD: 1
# Ivan Wu: 1
# Rianne Oosterkamp, MD: 1
# David Ostry: 1
# Todd C Lee, MD MPH FIDSA: 1
# Stephanie Lheureux: 1
# Jing Sun, MD, Ph.D: 1
# Chao-Chi Ho, MD, PhD: 1
# Peter Fasching, Prof. Dr. med.: 1
# Christian Castilla López, MsC: 1
# Rumen Benchev, Prof: 1
# Cavan Reilly, PhD: 1
# Rena Jones, Ph.D.: 1
# Graham Foster, MBBS: 1
# Erika Matos, PhD: 1
# T. John Winhusen, PhD.: 1
# Alexis MOSCA, MD: 1
# Jean L Rouleau, MD,PhD: 1
# Christoper Barker, MD: 1
# Kenneth W. Merrell, MD: 1
# Helen Storr, PhD: 1
# Sumit Gupta: 1
# Stephen Fremes, MD,MSc,FRCSC: 1
# Anders Thorell, Professor: 1
# Jean-Philippe Drouin-Chartier, PhD: 1
# Jin H. Han, MD: 1
# Henrik Grönberg, MD, PhD: 1
# Andreas Trojan, Prof. Dr. med.: 1
# Michael Hawkes, MD, PhD: 1
# Christopher J Melani: 1
# Brian Vickery, MD: 1
# Jacques Izard, PhD: 1
# Sarah Prinsloo: 1
# Sarah Yip, PhD, MSc: 1
# Vicky Makker, MD: 1
# Lead Investigator: 1
# Motolani Adedipe, PhD, DPh, MS: 1
# Chaohui Yu, Doctor: 1
# JoAnna K Leyenaar, MD, PhD: 1
# Sean M Oser, MD, MPH: 1
# Andrew Kneebone: 1
# Martin Muckley, FRCPI: 1
# Jennifer Johansson, MS: 1
# Michael Houghton, PhD: 1
# Mark Lazarev, MD: 1
# Peter Pellegrino, MD: 1
# Trevor Duffy: 1
# Dustin C Lee, PhD: 1
# Annette DeVito Dabbs, PhD: 1
# Crystal D Karakochuk, PhD: 1
# Vatinee Bunya, MD: 1
# Giorgia Sulis, PhD: 1
# Kent Nilsson, MD: 1
# Kristen Lindgren, PhD, ABPP: 1
# Michael Goggins, MD: 1
# Allison Gibson, PhD: 1
# Jonathan B. Bricker: 1
# Emily A Kringle, PhD, OTR/L: 1
# Alethea Desrosiers: 1
# rana ka Abuzaid, orthodontist: 1
# Xiaoli Nan: 1
# Ismaël Conejero: 1
# Etta Pisano: 1
# Lorne Tyrrell, MD PhD: 1
# Saumil Gandhi, MD: 1
# Spiridon Todorov, Prof, PhD: 1
# Ralph DeFronzo, MD: 1
# Aaron Shafer, MD: 1
# Nicolas Palaskas, MD: 1
# Reza Hejazi, MD: 1
# Andreas M Fritzen, Associate Professor: 1
# Karen Dzhambazov, Prof, PhD: 1
# Elias Jabbour: 1
# Edelgard Lindhoff-Last, Professor: 1
# Regina Rabinovich: 1
# Vania Youroukova, Prof, PhD: 1
# Nathan Congdon, MD: 1
# Dahui Wang, MD-PhD: 1
# Nicola Canessa, PhD: 1
# Guillaume Maquis-Gravel, MD,MSc: 1
# Abraham Wu, MD: 1
# Shira Goldenberg, PhD: 1
# Sonja Merten, MD MPH PhD: 1
# Paolo F. Caimi, MD: 1
# Luigi Ferrucci, M.D.: 1
# Erica C. Kaye, MD, MPH: 1
# Pianosi Paolo, MD: 1
# Srivandana Akshintala: 1
# Howard M Katzenstein: 1
# Anna Maria Hibbs, MD, MSCE: 1
# Tamara K Oser, MD: 1
# Anna De Simoni, PhD: 1
# Kerri Winters-Stone: 1
# Tokiko Hamasaki, PhD: 1
# John A Sauceda, PhD: 1
# Laurie E Cutting, PhD: 1
# Sivasubramanium Bhavani, MD: 1
# Claudia Fox, MD, MPH: 1
# CORALIE NOEL: 1
# Jeffrey M Jacobson: 1
# Summer Hanson, MD, PhD, FACS: 1
# Abdusalom Abdurakhmanov, MD: 1
# Murielle Roussel, MD: 1
# Liqun Jiao, MD: 1
# Carlos A Zarate, M.D.: 1
# Ajay Premkumar, MD: 1
# Boris Bogov, Prof, PhD: 1
# Hans-Christoph Friederich, Prof. Dr.: 1
# Adeyemi Ogunleye, MD: 1
# Anna H. Grummon, PhD: 1
# Sümeyye Akçay, PT: 1
# Julie Heimbach: 1
# Muhammad Zarak Awais, MBBS: 1
# Mark O'Hara, MD: 1
# Vaishalee Kenkre, MD: 1
# Holly Wyatt, MD: 1
# John Heinzerling, MD: 1
# Claudia Campbell, PhD: 1
# Alaine E Reschke-Hernandez, PhD: 1
# Andreas Peyrl, MD: 1
# Veronkia Bachanova: 1
# Milos Velinovic, MD, PhD: 1
# Yash B. Joshi, MD PhD: 1
# Elizabeth McClure, PhD: 1
# John H Joseph, MD: 1
# Gareth R Dutton, PhD: 1
# Jennifer Ellis, Ph.D.: 1
# Alaine E. Reschke-Hernandez, PhD: 1
# Helge Möllmann: 1
# Kubra Alpay, PhD: 1
# Ihsan Salloum, MD: 1
# Justin Gregg, MD: 1
# Laure Joseph, M.D.: 1
# Lucas Boersma, Prof. MD.: 1
# Claus Cursiefen, Prof. Dr.: 1
# Zeeshan Afzal, FCPS: 1
# David Darrow, MD: 1
# Amanda Rao, PhD: 1
# Eugenio Fernandez: 1
# Rodabe N. Amaria, MD: 1
# Margaret MacMillan: 1
# Martin K. Kankam, MD, PhD, MPH, FAPCR: 1
# Carla S Stover, Ph.D.: 1
# Carrie L Pistenmaa, MD, MS: 1
# Mario Gaudino, MD,PhD: 1
# Jeffrey R Wozniak, Ph.D.: 1
# Marianna Koczywas: 1
# Ana Oaknin, MD: 1
# Megan Marie Kelly, PhD MS: 1
# Johann Bauersachs, Prof. Dr.: 1
# Sherman Holtan, MD: 1
# Marie Roguski, MD MPH: 1
# Jing Chen, PhD: 1
# Federico Linassi, MD: 1
# Krishan R. Jethwa, MD: 1
# Wolfgang Kemmler, PhD: 1
# Kevin Hall, Ph.D.: 1
# Xavier MOISSET: 1
# Monali Vasekar, MD: 1
# Stuart S Winter: 1
# Heather Kaplan, MD, MSCE: 1
# Jessica Ansari, MD, MS: 1
# Anxo Fernandez-Ferreiro, PhD: 1
# Yan Ma, MD: 1
# Dawood Sayed, MD: 1
# Guliano Cerulli, MD: 1
# Alain SAAD, MD: 1
# Anne-Sophie Brazeau, PhD: 1
# Kathryn Glaser: 1
# Eva Szigethy: 1
# Valérie BENOIT: 1
# Nikolay Sapundziev, Prof, PhD: 1
# Jonatan Ruiz Ruiz, Dr.: 1
# Damien GUINDOLET: 1
# Dominique BREMOND-GIGNAC, MD: 1
# Rona Yaegar, MD: 1
# Cédric LAMIREL, MD: 1
# Simon Wernhart, MD: 1
# Kelli J England, PhD: 1
# Kiminori Kimura, MD: 1
# Michael Koenigs, PhD: 1
# Emily G McDonald, MD MSC: 1
# Guido Beldi: 1
# Maura L Gillison: 1
# Michael R Harrison, MD: 1
# Damiano Rondelli, MD: 1
# Stefan Leucht, MD: 1
# Bouthaina S Dabaja: 1
# Alice L Yu: 1
# Pinghong Zhou, MD, PhD: 1
# Lora Giangregorio, PhD: 1
# Thet Lynn, MD, MMedSc Global Health: 1
# Sara Ramel, MD: 1
# Mary Billstrand, MD: 1
# Charles Powell, DDS, MS: 1
# Leonard A Bradshaw, PhD: 1
# J. Sven D. Mieog, MD PhD: 1
# TBD TBD: 1
# Ugur T. Sener, MD: 1
# Kevin Krull, PhD: 1
# Lisa S. Chow, MD: 1
# Michele Bedard-Gilligan, PhD: 1
# Puyu Su, Professor: 1
# Michelle L Hermiston: 1
# Milena Encheva, MD, PhD: 1
# Anna GEMAHLING, MD: 1
# Aung Naing, Md: 1
# Marina Caskey, MD: 1
# Emily G McDonald, MD MSc: 1
# Miae OH: 1
# Kristen Kelley: 1
# Jan Reidar Stiegler, PhD: 1
# Massimo Volpe, Professor: 1
# David R Smith, Ph.D.: 1
# Eric GABISON, MD: 1
# John B. Liao: 1
# Pamela Samson, M.D., MPHS: 1
# Keith Choate, MD, PhD: 1
# Jessica A Reese, PhD: 1
# Ock K Chun, PhD: 1
# Edward G Clark, MD MSc FRCPC: 1
# David Kim, DDS, DMSc: 1
# Ecaterina E Dumbrava: 1
# Carlos Chaccour: 1
# Michele Staton, MSW, PhD: 1
# Hannah Linden: 1
# Ville Sallinen, MD, PhD: 1
# Jieer Ying, MD: 1
# Paul Mulholland: 1
# Nancy F Krebs, MD, MS: 1
# Ghazala Saleem, EdD: 1
# Rebecca Sartini, DNP: 1
# Vanessa Meier-Stephenson, MD, PhD: 1
# Rosen Nikolov, Prof, MD: 1
# Aaron Folsom, MD, MPH: 1
# Diwakar Davar, MD, M.Sc: 1
# Frank A Bucci, MD: 1
# Frederique Paulus, prof. dr.: 1
# Marion Rabant, M.D., PhD: 1
# Steven R Grossman, MD: 1
# Werner Bischoff, MD: 1
# Qianyu Zhuang, Professor: 1
# John Villano, MD, PhD: 1
# Sacha NAHON ESTEVE: 1
# Olcay Aycicek, Asist Prof: 1
# Audrey Harkness, PhD: 1
# Savannah Partridge: 1
# Rachel Freedman, MD MPH: 1
# Mark B Geyer, MD: 1
# James I Geller: 1
# Michael Good, MD, PhD: 1
# Kate V Meriwether, MD: 1
# Elizabeth Brem, MD: 1
# Surya P Bhatt, MD, MSPH: 1
# Matthew Tennant, MD, FRCSC: 1
# Manali I Patel, MD MPH MS: 1
# DINO TIKVESA, MD: 1
# Patrick J Smith, PhD, MPH: 1
# Funda Meric-Bernstam: 1
# Vanphanom Sychareun, MD, PhD: 1
# Carolyn Bramante, MD: 1
# Natalie Lockney, MD: 1
# Suzanne Wolden, MD: 1
# Lori J. Wirth, MD: 1
# Lai Wei: 1
# Afton Hassett: 1
# Wilson Z Ray, MD: 1
# Principal Investigator: 1
# Alain SAAD: 1
# Sophie Susen, MD, Professor: 1
# Giorgio Gastaldi, MD, DDS: 1
# Kelsey M Cochrane, PhD: 1

# %%
final_collection.count_documents(
    {
        "locations": {
            "$elemMatch": {
                "facility": {"$regex": "Orange County Research Center", "$options": "i"}
            }
        }
    }
)
# Out:
# 3

# %%
final_collection.count_documents(
    {"locations": {"$elemMatch": {"facility": {"$regex": "Orange", "$options": "i"}}}}
)
# Out:
# 13

# %%
for trial in final_collection.find(
    {"locations": {"$elemMatch": {"facility": {"$regex": "Orange", "$options": "i"}}}}
):
    for location in trial.get("locations", []):
        pprint.pprint(location["facility"])
# Out:
# "Children's Hospital of Alabama"
# 'University of Alabama at Birmingham Cancer Center'
# 'USA Health Strada Patient Care Center'
# 'Phoenix Childrens Hospital'
# 'Banner University Medical Center - Tucson'
# "Arkansas Children's Hospital"
# 'University of Arkansas for Medical Sciences'
# 'Kaiser Permanente Downey Medical Center'
# 'Loma Linda University Medical Center'
# "Miller Children's and Women's Hospital Long Beach"
# "Children's Hospital Los Angeles"
# 'Cedars Sinai Medical Center'
# "Valley Children's Hospital"
# "UCSF Benioff Children's Hospital Oakland"
# 'Kaiser Permanente-Oakland'
# "Children's Hospital of Orange County"
# "Lucile Packard Children's Hospital Stanford University"
# 'Sutter Medical Center Sacramento'
# 'University of California Davis Comprehensive Cancer Center'
# "Rady Children's Hospital - San Diego"
# 'Naval Medical Center -San Diego'
# 'UCSF Medical Center-Parnassus'
# 'UCSF Medical Center-Mission Bay'
# 'Santa Barbara Cottage Hospital'
# "Children's Hospital Colorado"
# "Rocky Mountain Hospital for Children-Presbyterian Saint Luke's Medical Center"
# "Connecticut Children's Medical Center"
# 'Yale University'
# 'Alfred I duPont Hospital for Children'
# 'MedStar Georgetown University Hospital'
# "Children's National Medical Center"
# 'Broward Health Medical Center'
# 'Lee Memorial Health System'
# "Golisano Children's Hospital of Southwest Florida"
# 'University of Florida Health Science Center - Gainesville'
# "Memorial Regional Hospital/Joe DiMaggio Children's Hospital"
# "Nemours Children's Clinic-Jacksonville"
# 'University of Miami Miller School of Medicine-Sylvester Cancer Center'
# "Nicklaus Children's Hospital"
# 'Miami Cancer Institute'
# 'AdventHealth Orlando'
# 'Arnold Palmer Hospital for Children'
# "Nemours Children's Clinic - Orlando"
# 'Orlando Health Cancer Institute'
# "Nemours Children's Hospital"
# "Nemours Children's Clinic - Pensacola"
# "Johns Hopkins All Children's Hospital"
# "Saint Joseph's Hospital/Children's Hospital-Tampa"
# "Saint Mary's Hospital"
# "Children's Healthcare of Atlanta - Arthur M Blank Hospital"
# 'Memorial Health University Medical Center'
# 'University of Hawaii Cancer Center'
# 'Kapiolani Medical Center for Women and Children'
# 'Tripler Army Medical Center'
# "Saint Luke's Cancer Institute - Boise"
# "Lurie Children's Hospital-Chicago"
# 'University of Illinois'
# 'University of Chicago Comprehensive Cancer Center'
# 'Loyola University Medical Center'
# "Advocate Children's Hospital-Oak Lawn"
# "Advocate Children's Hospital-Park Ridge"
# 'Advocate Lutheran General Hospital'
# 'Saint Jude Midwest Affiliate'
# 'Southern Illinois University School of Medicine'
# 'Riley Hospital for Children'
# 'Ascension Saint Vincent Indianapolis Hospital'
# "Blank Children's Hospital"
# 'University of Iowa/Holden Comprehensive Cancer Center'
# 'University of Kentucky/Markey Cancer Center'
# "Norton Children's Hospital"
# 'Tulane University School of Medicine'
# "Children's Hospital New Orleans"
# 'Ochsner Medical Center Jefferson'
# 'Eastern Maine Medical Center'
# "Maine Children's Cancer Program"
# 'Sinai Hospital of Baltimore'
# 'Walter Reed National Military Medical Center'
# 'Massachusetts General Hospital Cancer Center'
# 'Dana-Farber Cancer Institute'
# 'UMass Memorial Medical Center - University Campus'
# "C S Mott Children's Hospital"
# 'Wayne State University/Karmanos Cancer Institute'
# 'Henry Ford Health Saint John Hospital'
# 'Michigan State University Clinical Center'
# 'Hurley Medical Center'
# "Corewell Health Grand Rapids Hospitals - Helen DeVos Children's Hospital"
# 'Bronson Methodist Hospital'
# 'Kalamazoo Center for Medical Studies'
# "Children's Hospitals and Clinics of Minnesota - Minneapolis"
# 'University of Minnesota/Masonic Cancer Center'
# 'Mayo Clinic in Rochester'
# 'University of Mississippi Medical Center'
# "University of Missouri Children's Hospital"
# "Children's Mercy Hospitals and Clinics"
# 'Washington University School of Medicine'
# 'Mercy Hospital Saint Louis'
# "Children's Hospital and Medical Center of Omaha"
# 'University of Nebraska Medical Center'
# 'University Medical Center of Southern Nevada'
# 'Sunrise Hospital and Medical Center'
# 'Alliance for Childhood Diseases/Cure 4 the Kids Foundation'
# 'Summerlin Hospital Medical Center'
# 'Nevada Cancer Research Foundation NCORP'
# 'Dartmouth Hitchcock Medical Center/Dartmouth Cancer Center'
# 'Hackensack University Medical Center'
# 'Morristown Medical Center'
# "Saint Peter's University Hospital"
# 'Rutgers Cancer Institute of New Jersey-Robert Wood Johnson University Hospital'
# 'Newark Beth Israel Medical Center'
# "Saint Joseph's Regional Medical Center"
# 'Overlook Hospital'
# 'University of New Mexico Cancer Center'
# 'Albany Medical Center'
# 'Montefiore Medical Center - Moses Campus'
# 'Roswell Park Cancer Institute'
# 'NYU Langone Hospital - Long Island'
# "The Steven and Alexandra Cohen Children's Medical Center of New York"
# 'Laura and Isaac Perlmutter Cancer Center at NYU Langone'
# 'Mount Sinai Hospital'
# ('NYP/Columbia University Medical Center/Herbert Irving Comprehensive Cancer '
#  'Center')
# 'Memorial Sloan Kettering Cancer Center'
# 'University of Rochester'
# 'State University of New York Upstate Medical University'
# 'New York Medical College'
# 'Mission Hospital'
# 'UNC Lineberger Comprehensive Cancer Center'
# 'Carolinas Medical Center/Levine Cancer Institute'
# 'Novant Health Presbyterian Medical Center'
# 'Duke University Medical Center'
# 'East Carolina University'
# 'Wake Forest University Health Sciences'
# "Children's Hospital Medical Center of Akron"
# "Cincinnati Children's Hospital Medical Center"
# 'Rainbow Babies and Childrens Hospital'
# 'Cleveland Clinic Foundation'
# "Nationwide Children's Hospital"
# "Dayton Children's Hospital"
# "Mercy Children's Hospital"
# 'University of Oklahoma Health Sciences Center'
# "Legacy Emanuel Children's Hospital"
# 'Legacy Emanuel Hospital and Health Center'
# 'Oregon Health and Science University'
# "Penn State Children's Hospital"
# "Children's Hospital of Philadelphia"
# "Saint Christopher's Hospital for Children"
# "Children's Hospital of Pittsburgh of UPMC"
# 'Rhode Island Hospital'
# 'Medical University of South Carolina'
# 'Prisma Health Richland Hospital'
# "BI-LO Charities Children's Cancer Center"
# 'Greenville Cancer Treatment Center'
# 'Sanford USD Medical Center - Sioux Falls'
# "T C Thompson Children's Hospital"
# 'East Tennessee Childrens Hospital'
# "Saint Jude Children's Research Hospital"
# "The Children's Hospital at TriStar Centennial"
# 'Vanderbilt University/Ingram Cancer Center'
# "Dell Children's Medical Center of Central Texas"
# "Driscoll Children's Hospital"
# 'Medical City Dallas Hospital'
# 'UT Southwestern/Simmons Cancer Center-Dallas'
# "El Paso Children's Hospital"
# 'Brooke Army Medical Center'
# "Cook Children's Medical Center"
# 'Baylor College of Medicine/Dan L Duncan Comprehensive Cancer Center'
# 'UMC Cancer Center / UMC Health System'
# "Children's Hospital of San Antonio"
# "Methodist Children's Hospital of South Texas"
# 'University of Texas Health Science Center at San Antonio'
# 'Scott and White Memorial Hospital'
# "Primary Children's Hospital"
# 'University of Virginia Cancer Center'
# 'Inova Fairfax Hospital'
# "Children's Hospital of The King's Daughters"
# 'Virginia Commonwealth University/Massey Cancer Center'
# "Carilion Children's"
# "Seattle Children's Hospital"
# "Providence Sacred Heart Medical Center and Children's Hospital"
# "Mary Bridge Children's Hospital and Health Center"
# 'Madigan Army Medical Center'
# 'West Virginia University Charleston Division'
# 'West Virginia University Healthcare'
# 'University of Wisconsin Carbone Cancer Center - University Hospital'
# "Children's Hospital of Wisconsin"
# "John Hunter Children's Hospital"
# "The Children's Hospital at Westmead"
# "Women's and Children's Hospital-Adelaide"
# 'Princess Margaret Hospital for Children'
# 'Instituto De Oncologia Pediatrica'
# "Alberta Children's Hospital"
# "British Columbia Children's Hospital"
# 'CancerCare Manitoba'
# 'IWK Health Centre'
# "McMaster Children's Hospital at Hamilton Health Sciences"
# 'Kingston Health Sciences Centre'
# "Children's Hospital of Eastern Ontario"
# 'Hospital for Sick Children'
# "The Montreal Children's Hospital of the MUHC"
# 'Centre Hospitalier Universitaire Sainte-Justine'
# 'Saskatoon Cancer Centre'
# "CHU de Quebec-Centre Hospitalier de l'Universite Laval (CHUL)"
# 'Fukushima Medical University Hospital'
# 'Kagoshima University Medical Dental Hospital'
# 'Shizuoka Cancer Center'
# 'Nihon University Itabashi Hospital'
# 'Hiroshima University Hospital'
# 'National Cancer Center Hospital'
# "San Jorge Children's Hospital"
# 'University Pediatric Hospital'
# 'University of Arizona Cancer Center ( Site 0018)'
# 'Comprehensive Blood & Cancer Center [Bakersfield, CA] ( Site 0054)'
# 'California Cancer Associates for Research & Excellence ( Site 0016)'
# 'The Angeles Clinic and Research Institute ( Site 0005)'
# 'UCLA Hematology/Oncology - Westwood (Building 100) ( Site 0009)'
# ('University of California, Irvine (UCI) Health - UC Irvine Medical Center ( '
#  'Site 0076)')
# 'UCSF Helen Diller Family Comprehensive Cancer Center ( Site 0004)'
# "Providence Saint John's Health Center ( Site 0059)"
# 'University of Colorado Cancer Center ( Site 0021)'
# 'Yale Cancer Center ( Site 0014)'
# 'Georgetown University Medical Center ( Site 0023)'
# 'Holy Cross Hospital, Michael & Dianne Bienes Comp Cancer Ctr ( Site 0022)'
# 'Baptist MD Anderson Cancer Center ( Site 0083)'
# 'Mount Sinai Medical Center Comprehensive Cancer Center ( Site 0031)'
# 'Moffitt Cancer Center ( Site 0011)'
# 'Emory School of Medicine ( Site 0013)'
# 'Augusta University ( Site 0077)'
# 'Northwest Georgia Oncology Centers PC ( Site 0061)'
# 'Kaiser Permanente Moanalua Medical Center ( Site 0063)'
# 'The University of Chicago ( Site 0020)'
# 'University of Iowa Hospital and Clinics ( Site 0026)'
# 'James Graham Brown Cancer Center ( Site 0058)'
# 'Mercy Health-Paducah Cancer Center ( Site 0084)'
# 'MedStar Franklin Square Medical Center ( Site 0046)'
# 'Sidney Kimmel Comprehensive Cancer Center at Johns Hopkins ( Site 0056)'
# 'Massachusetts General Hospital ( Site 0041)'
# 'Dana-Farber Cancer Institute ( Site 0006)'
# 'Karmanos Cancer Institute ( Site 0047)'
# 'Mayo Clinic in Rochester, Minnesota ( Site 0002)'
# 'Comprehensive Cancer Centers of Nevada ( Site 0043)'
# ('John Theurer Cancer Center at Hackensack University Medical Center ( Site '
#  '0038)')
# 'Cancer Institute of New Jersey ( Site 0025)'
# 'Laura and Isaac Perlmutter Cancer Center at NYU Langone Health ( Site 0032)'
# 'Memorial Sloan Kettering Cancer Center ( Site 0012)'
# 'White Plains Hospital-Center for Cancer Care ( Site 0069)'
# 'WakeMed Cancer Care - Waverly Hematology & Medical Oncology ( Site 0074)'
# 'University of North Carolina at Chapel Hill ( Site 0040)'
# 'Levine Cancer Institute ( Site 0034)'
# 'Duke Cancer Center ( Site 0028)'
# 'Sanford Fargo Medical Center-Roger Maris Cancer Center ( Site 0065)'
# 'University Hospitals ( Site 0044)'
# 'Oklahoma Cancer Specialists and Research Institute, LLC ( Site 0082)'
# 'Providence Portland Medical Center ( Site 0051)'
# "St. Luke's University Health Network ( Site 0017)"
# 'University of Pennsylvania ( Site 0010)'
# 'Fox Chase Cancer Center ( Site 0042)'
# 'UPMC Hillman Cancer Center ( Site 0008)'
# 'Sanford Cancer Center ( Site 0066)'
# 'West Cancer Center and Research Institute ( Site 0055)'
# 'Vanderbilt Health One Hundred Oaks Diagnostic ( Site 0060)'
# 'Vanderbilt Ingram Cancer Center ( Site 0015)'
# 'Texas Oncology-Baylor Sammons Cancer Center ( Site 0062)'
# 'University of Texas MD Anderson Cancer Center ( Site 0007)'
# 'South Texas Accelerated Research Therapeutics, LLC (START) ( Site 0001)'
# 'University of Virginia Health System ( Site 0035)'
# 'Bon Secours St. Francis Medical Center-Oncology Research ( Site 0075)'
# 'Blue Ridge Cancer Care ( Site 0067)'
# 'Fred Hutchinson Cancer Center ( Site 0024)'
# 'Centro de Oncología e Investigación de Buenos Aires ( Site 1357)'
# 'Instituto Alexander Fleming ( Site 1364)'
# 'IDIM - Instituto de Investigaciones Metabólicas ( Site 1362)'
# 'Instituto de Investigaciones Clínicas Mar del Plata ( Site 1363)'
# 'Clinica Viedma ( Site 1353)'
# 'Sanatorio Parque ( Site 1355)'
# 'Instituto de Oncologia de Rosario ( Site 1350)'
# 'Hospital Provincial del Centenario ( Site 1359)'
# 'Hospital Aleman-Oncology ( Site 1351)'
# 'Hospital Privado Universitario de Córdoba ( Site 1354)'
# 'Fundación CORI para la Investigación y Prevención del Cáncer ( Site 1358)'
# 'Centro Medico San Roque-Oncology ( Site 1352)'
# 'Chris OBrien Lifehouse ( Site 3003)'
# ('Royal Prince Alfred Hospital-A.W. Morrow Gastroenterology and Liver Centre ( '
#  'Site 3016)')
# 'Liverpool Hospital-Medical Oncology ( Site 3021)'
# 'Macquarie University ( Site 3010)'
# 'Mater Hospital Sydney ( Site 3007)'
# 'Orange Hospital-Clinical Trials Unit ( Site 3027)'
# ('Port Macquarie - Mid North Coast Cancer Institute-Medical Oncology ( Site '
#  '3020)')
# 'Royal North Shore Hospital-Medical Oncology Clinical Trials ( Site 3025)'
# 'Calvary Mater Newcastle ( Site 3005)'
# 'Westmead Hospital ( Site 3000)'
# 'Melanoma Institute Australia ( Site 3001)'
# 'Mater Misericordiae Limited-Medical Oncology ( Site 3019)'
# 'Gallipoli Medical Research Ltd ( Site 3011)'
# 'Royal Brisbane and Women s Hospital ( Site 3009)'
# 'Tasman Oncology Research Pty Ltd ( Site 3012)'
# 'The Townsville Hospital ( Site 3017)'
# 'Princess Alexandra Hospital ( Site 3002)'
# 'Royal Adelaide Hospital ( Site 3014)'
# 'The Queen Elizabeth Hospital ( Site 3026)'
# 'Monash Health ( Site 3015)'
# 'Austin Health-Austin Hospital ( Site 3004)'
# ('Peter MacCallum Cancer Centre-Parkville Cancer Clinical Trials Unit (PCCTU) '
#  '( Site 3008)')
# "St Vincent's Hospital-Oncology Clinical Trials ( Site 3018)"
# 'Western Health-Sunshine & Footscray Hospitals ( Site 3023)'
# 'Ballarat Oncology & Haematology Services ( Site 3022)'
# 'Sir Charles Gairdner Hospital ( Site 3006)'
# 'St John of God Subiaco Hospital ( Site 3013)'
# 'Kepler Universitätsklinikum ( Site 2955)'
# 'Medical University of Graz ( Site 2952)'
# 'Medizinische Universitaet Innsbruck ( Site 2951)'
# 'Uniklinikum Salzburg ( Site 2956)'
# 'Medizinische Universität Wien ( Site 2953)'
# 'Klinik Floridsdorf-Abteilung für Innere Medizin und Pneumologie ( Site 2954)'
# 'AZ Sint-Maarten ( Site 2904)'
# 'Institut Jules Bordet ( Site 2903)'
# 'UZ Brussel ( Site 2900)'
# 'Cliniques Universitaires de Bruxelles - CUB - Hopital Erasme ( Site 2905)'
# 'AZ Maria Middelares ( Site 2908)'
# 'UZ Leuven ( Site 2901)'
# 'UZ Leuven - Campus Gasthuisberg ( Site 2906)'
# 'UZ Leuven Gasthuisberg, Gynaecologie-Verloskunde ( Site 2907)'
# ('Université Catholique de Louvain-Namur - Centre Hospitalier Universitaire '
#  'Dinant-Godinne - Site Godi')
# 'CRIO - CENTRO REGIONAL INTEGRADO DE ONCOLOGIA-Pesquisa Clínica ( Site 1024)'
# 'ONCOSITE - Centro de Pesquisa Clinica em Oncologia ( Site 1008)'
# 'Hospital de Clinicas de Porto Alegre ( Site 1000)'
# 'Hospital São Lucas da PUCRS-Centro de Pesquisa em Oncologia ( Site 1006)'
# 'Hospital Nossa Senhora da Conceição ( Site 1011)'
# 'Clinica Viver ( Site 1021)'
# 'CEPON ( Site 1012)'
# 'Fundação Pio XII - Hospital de Câncer de Barretos ( Site 1010)'
# ('Fundação Faculdade Regional de Medicina de São José do Rio Preto-Centro '
#  'Integrado de Pesquisa ( Site')
# ('Clínica de Pesquisa e Centro de Estudos em Ginecologia Oncológica e Mamária '
#  'LTDA ( Site 1017)')
# 'Instituto Nacional de Câncer José Alencar Gomes da Silva - INCA ( Site 1020)'
# 'Instituto de de Educação, pesquisa e Gestão em Saúde ( Site 1014)'
# 'Instituto do Cancer do Estado de Sao Paulo - ICESP ( Site 1001)'
# 'A. C. Camargo Cancer Center ( Site 1002)'
# 'Cross Cancer Institute ( Site 2804)'
# 'Hamilton Health Sciences-Juravinski Cancer Centre ( Site 2801)'
# 'Kingston Health Sciences Centre-Kingston General Hospital Site ( Site 2808)'
# 'London Regional Cancer Program - LHSC ( Site 2806)'
# 'The Ottawa Hospital - General Campus ( Site 2813)'
# 'Sunnybrook Research Institute ( Site 2802)'
# 'Mount Sinai Hospital ( Site 2811)'
# 'Princess Margaret Cancer Centre ( Site 2803)'
# ('Centre Intégré de Santé et de Services Sociaux de la '
#  'Montérégie-Centre-Oncology ( Site 2809)')
# ('Centre Intégré de Santé et de Services Sociaux (CISSS) de La-Centre intégré '
#  'de cancérologie de Lava')
# 'Centre Hospitalier de l Universite de Montreal - CHUM ( Site 2807)'
# 'Jewish General Hospital ( Site 2800)'
# ("Centre intégré universitaire de santé et de services sociaux de l'Estrie - "
#  'Centre Hospitalier Univer')
# ('Centre integre universitaire de sante et de services sociaux de la '
#  'Mauricie-et-du-centre-du-quebec (')
# ('Centre intégré de cancérologie du CHU de Québec Université Laval, Hôpital de '
#  "l'Enfant-Jésus ( Site 2")
# 'James Lind Centro de Investigacion del Cancer ( Site 2757)'
# 'Orlandi Oncologia-Oncology ( Site 2752)'
# 'Fundacion Arturo Lopez Perez FALP ( Site 2750)'
# 'Oncovida ( Site 2759)'
# 'Pontificia Universidad Catolica de Chile-Hemato-Oncology ( Site 2751)'
# 'Instituto Nacional del Cancer-CR Investigación ( Site 2753)'
# 'Bradfordhill-Clinical Area ( Site 2756)'
# 'ONCOCENTRO APYS-ACEREY ( Site 2758)'
# 'Centro de Investigaciones ( Site 2755)'
# 'Anhui Provincial Hospital-Cancer Chemotherapy Department ( Site 3480)'
# 'Anhui Provincil Hospital South District-Respiratory Medicine Dept ( Site 3487)'
# 'Beijing Cancer Hospital ( Site 3451)'
# ('Affiliated Hospital of Military Medical Science Academy of the PLA ( Site '
#  '3465)')
# 'Beijing Cancer hospital-Thoracic Cancer Department A ( Site 3454)'
# 'Beijing Peking Union Medical College Hospital-Medical Oncology ( Site 3466)'
# ("Army Medical Center of People's Liberation Army-Oncology Department ( Site "
#  '3477)')
# 'Fujian Provincial Cancer Hospital ( Site 3461)'
# 'Southern medical university Nangfang Hospital ( Site 3490)'
# ('The First Affiliated Hospital, Sun Yat-sen University-pneumology department '
#  '( Site 3459)')
# 'The Sixth Affiliated Hospital of Sun Yat-sen University ( Site 3491)'
# 'SUN YAT-SEN UNIVERSITY CANCER CENTRE-Internal Medicine ( Site 3452)'
# 'Sun Yat-sen University Cancer Center-melanoma ( Site 3482)'
# "Guangdong Provincial People's Hospital-Cancer Center ( Site 3462)"
# ('The First Affiliated Hospital of Guangzhou Medical University-thoracic '
#  'surgery department ( Site 346')
# ('Harbin Medical University Cancer Hospital-Harbin Medical University Cancer '
#  'Hospital ( Site 3475)')
# 'Tongji Hospital Tongji Medical,Science & Technology-oncology ( Site 3476)'
# ('Union Hospital Tongji Medical College Huazhong University of Science and '
#  'Technology ( Site 3492)')
# 'Xiangya Hospital Central South University-Respiratory ( Site 3479)'
# 'Hunan Cancer Hospital ( Site 3485)'
# 'Jiangsu Cancer Hospital-Medical Oncotherapy ( Site 3469)'
# "Northern Jiangsu People's Hospital-General Surgery Department ( Site 3474)"
# 'The First Hospital of Jilin University-Oncology ( Site 3464)'
# 'Jilin Province Tumor Hospital ( Site 3484)'
# ('Tangdu Hospital of Fourth Military Medical University of Chi-department of '
#  'radiotherapy ( Site 3455)')
# 'Fudan University Shanghai Cancer Center ( Site 3467)'
# 'Shanghai Pulmonary Hospital ( Site 3470)'
# 'The First Affiliated Hospital of Xi an Jiaotong University ( Site 3489)'
# 'West China Hospital Sichuan University-respiratory ( Site 3473)'
# 'Tianjin Medical University Cancer Institute and Hospital ( Site 3456)'
# ('Xinjiang Medical University Cancer Hospital - Urumqi-galactophore department '
#  '( Site 3486)')
# 'Hangzhou Cancer Hospital-Medical Oncology ( Site 3468)'
# 'Zhejiang Cancer Hospital ( Site 3481)'
# 'Instituto de Cancerología-Oncology ( Site 2702)'
# 'Fundacion Colombiana de Cancerología Clinica Vida ( Site 2707)'
# 'Clinica de la Costa S.A.S. ( Site 2705)'
# 'Sociedad De Oncología y Hematología Del Cesar SAS-Oncology ( Site 2704)'
# 'Oncomédica S.A.S ( Site 2703)'
# 'Instituto Nacional De Cancerologia-Oncología Clínica ( Site 2706)'
# 'Administradora Country S.A. ( Site 2701)'
# 'Fundación Valle del Lili ( Site 2700)'
# 'Clínica Imbanaco S.A.S ( Site 2708)'
# 'Masarykuv onkologicky ustav-Klinika komplexni onkologicke pece ( Site 0703)'
# 'Fakultni nemocnice Olomouc-Onkologicka klinika ( Site 0704)'
# 'Fakultni Thomayerova nemocnice-Onkologicka klinika 1. LF UK ( Site 0702)'
# ('Fakultni nemocnice v Motole-Onkologicka klinika 2. LF UK a FN Motol ( Site '
#  '0705)')
# 'Fakultni nemocnice Olomouc ( Site 0701)'
# 'Fakultni nemocnice v Motole ( Site 0700)'
# 'Odense Universitetshospital ( Site 0650)'
# 'Vejle Sygehus ( Site 0653)'
# 'Tartu University Hospital-Radiotherapy and oncology ( Site 3800)'
# 'Tampere University Hospital [Tampere Finland] ( Site 0600)'
# 'Turku University Hospital ( Site 0601)'
# ("Centre Hospitalier Universitaire de Nice - Hôpital l'Archet-Dermatology "
#  'Department ( Site 2539)')
# 'Nouvel Hôpital Civil (NHC) ( Site 2529)'
# 'CHU Bordeaux Haut-Leveque ( Site 2534)'
# 'Centre Hopitalar Leon-Berard ( Site 2519)'
# 'Hopital Nord ( Site 2516)'
# 'Hôpital Privé Clairval ( Site 2549)'
# 'CHU La Timone ( Site 2508)'
# 'Centre Georges François Leclerc-Centre de recherche clinique ( Site 2536)'
# 'CHU Jean Minjoz ( Site 2520)'
# 'CHRU Brest - Hopital Cavale Blanche ( Site 2504)'
# 'Institut Bergonie ( Site 2502)'
# 'CHU de Toulouse - Hopital Larrey-service de pneumologie ( Site 2526)'
# 'CHU Toulouse - Hopital Rangueil ( Site 2518)'
# 'Ambroise Pare Hopital ( Site 2503)'
# 'Hôpital Foch ( Site 2543)'
# 'Hôpital Beaujon ( Site 2524)'
# ('Groupe hospitalier Paris saint Joseph-Service de Pneumologie-Allergologie '
#  '-Oncologie Thoracique ( Si')
# 'Centre Eugène Marquis Rennes - Centre de Lutte Contre le Cancer ( Site 2525)'
# 'Hopital Trousseau ( Site 2512)'
# 'C.H.U. de Tours - Hopital Bretonneau ( Site 2515)'
# "Institut de Cancérologie de l'Ouest-Oncologie Médicale ( Site 2522)"
# ('Hôpital Nord Guillaume-et-René-Laennec / CHU de Nantes-lung oncology ( Site '
#  '2546)')
# 'Institut de Cancérologie de Lorraine Alexis Vautrin ( Site 2532)'
# 'CHRU Lille Hospital Claude Huriez ( Site 2506)'
# ('Centre Jean Perrin - Centre Régional de Lutte contre le Cancer '
#  "d'Auvergne-ONCOLOGY ( Site 2542)")
# 'CH Lyon Sud Hospices Civils de Lyon ( Site 2521)'
# 'C.H.U. Pontchaillou ( Site 2511)'
# 'Centre Hospitalier du Mans-Pneumologie ( Site 2527)'
# 'Hôpital Avicenne-Dermatologie ( Site 2538)'
# "Clinique de L'Europe ( Site 2548)"
# 'Centre Hopitalier Intercommunal Creteil ( Site 2514)'
# 'Hôpital Universitaire Paul Brousse ( Site 2541)'
# 'Institut Gustave Roussy ( Site 2513)'
# 'Centre Hospitalier Universitaire de Poitiers-Dermatologie ( Site 2544)'
# 'Hopital Cochin ( Site 2509)'
# 'Hopital Saint Louis ( Site 2510)'
# 'CHU Hopital Saint Antoine ( Site 2517)'
# 'Hôpital Tenon ( Site 2530)'
# 'Universitaetsklinikum Tuebingen ( Site 2405)'
# 'Universitätsklinikum Erlangen ( Site 2408)'
# 'Universitaetsklinik Muenchen ( Site 2406)'
# 'Krankenhaus Nordwest ( Site 2409)'
# 'Elbe Klinikum Buxtehude ( Site 2400)'
# 'Medizinische Hochschule Hannover ( Site 2402)'
# 'Universitaetsklinikum Essen ( Site 2404)'
# ('Universitaetsklinikum des Saarlandes-Klinik für Innere Medizin '
#  'V-Pneumologie, Allergologie, Beatmun')
# 'Universitatsklinikum Carl Gustav Carus ( Site 2407)'
# 'LungenClinic Grosshansdorf GmbH ( Site 2412)'
# 'SRH Wald-Klinikum Gera GmbH ( Site 2403)'
# ('Helios Klinikum Emil von Behring Berlin-Zehlendorf-Lungenklinik Heckeshorn ( '
#  'Site 2418)')
# 'Facharztzentrum Eppendorf ( Site 2415)'
# 'General Hospital of Athens "Laiko"-Hematology Department ( Site 1851)'
# 'Sotiria Regional Chest Diseases Hospital of Athens ( Site 1850)'
# 'Oncomedica ( Site 3401)'
# 'Grupo Medico Angeles ( Site 3402)'
# 'MEDI-K CAYALA ( Site 3403)'
# 'Queen Mary Hospital ( Site 1902)'
# 'Queen Mary Hospital-Department of Medicine (Respiratory) ( Site 1900)'
# 'Princess Margaret Hospital ( Site 1903)'
# ('Békés Megyei Központi Kórház Pándy Kálmán Tagkórház-Megyei Onkológiai '
#  'Centrum ( Site 1405)')
# ('Borsod-Abaúj-Zemplén Megyei Központi Kórház és Egyetemi Oktatókórház ( Site '
#  '1409)')
# 'Fejér Megyei Szent György Egyetemi Oktató Kórház-l.Pulmonologia ( Site 1407)'
# 'Jász-Nagykun-Szolnok Vármegyei Hetényi Géza Kórház ( Site 1401)'
# ('Országos Onkológiai Intézet-Urogenitális Tumorok és Klinikai Farmakológiai '
#  'Osztály ( Site 1411)')
# 'Markusovszky Egyetemi Oktatokorhaz-Onkológiai Osztály ( Site 1410)'
# 'Farkasgyepui Tudogyogyintezet-Pulmonologia ( Site 1414)'
# 'Semmelweis University-Belgyógyászati és Hematológiai Klinika ( Site 1406)'
# 'Orszagos Koranyi Pulmonologiai Intezet ( Site 1403)'
# 'Uzsoki Utcai Kórház-Onkoradiológiai Osztály ( Site 1413)'
# ('Debreceni Egyetem Klinikai Kozpont-Belgyógyászati Klinika (Haematologia) ( '
#  'Site 1415)')
# 'Debreceni Egyetem Klinikai Kozpont-Onkológiai Klinika ( Site 1412)'
# 'Somogy Megyei Kaposi Mor Oktato Korhaz ( Site 1402)'
# 'Zala Megyei Szent Rafael Korhaz ( Site 1400)'
# 'Mater Misercordiae University Hospital ( Site 1800)'
# 'Tallaght University Hospital ( Site 1803)'
# 'St. James s Hospital ( Site 1801)'
# 'Rambam Health Care Campus-Oncology Division ( Site 2053)'
# 'Hadassah Ein Kerem Medical Center ( Site 2051)'
# 'Rabin Medical Center ( Site 2059)'
# 'Chaim Sheba Medical Center ( Site 2055)'
# 'Chaim Sheba Medical Center. ( Site 2052)'
# 'Sourasky Medical Center ( Site 2054)'
# 'Shamir Medical Center Assaf Harofeh ( Site 2058)'
# 'Istittuto Nazionale dei Tumori Regina Elena IRCCS - IFO ( Site 1963)'
# ('Fondazione Policlinico Universitario Agostino Gemelli IRCCS -Medical '
#  'Oncology ( Site 1975)')
# 'Policlinico Universitario Agostino Gemelli ( Site 1965)'
# ('Fondazione IRCCS Istituto Nazionale dei Tumori-Struttura Complessa Oncologia '
#  'Medica 1 ( Site 1977)')
# 'Azienda Ospedaliera San Gerardo ( Site 1980)'
# 'Humanitas-U.O di Oncologia medica ed Ematologia ( Site 1968)'
# 'Ospedale San Luigi Gonzaga ( Site 1956)'
# 'IRCCS CRO Aviano, Hematology/Oncology ( Site 1957)'
# 'Ospedale Cannizzaro ( Site 1981)'
# 'Istituto di Candiolo - IRCCS ( Site 1960)'
# 'AO Santa Maria della Misericordia-Oncology Department ( Site 1971)'
# 'Istituto Oncologico Veneto IRCCS ( Site 1976)'
# 'Humanitas Gavazzeni ( Site 1954)'
# ('Azienda Socio Sanitaria Territoriale Papa Giovanni XXIII-UOC Oncologia ( '
#  'Site 1967)')
# 'Azienda Ospedaliera Spedali Civili di Brescia-Oncology ( Site 1972)'
# 'IRCCS A.O.U. San Martino - IST ( Site 1961)'
# 'Ospedale San Raffaele ( Site 1979)'
# 'Istituto Europeo di Oncologia ( Site 1952)'
# 'Istituto Nazionale Tumori IRCCS Fondazione Pascale ( Site 1955)'
# 'Azienda Ospedaliero Universitaria di Parma-UO Oncologia Medica ( Site 1964)'
# 'Azienda Ospedaliera San Camillo Forlanini ( Site 1958)'
# 'ospedale le scotte-U.O.C. Immunoterapia Oncologica ( Site 1969)'
# 'Azienda Ospedaliera Santa Maria ( Site 1962)'
# ('Azienda Ospedaliero-Universitaria Città della Salute e della Scienza di '
#  'Torino ( Site 1974)')
# 'Nagoya University Hospital ( Site 3151)'
# 'National Hospital Organization Nagoya Medical Center ( Site 3109)'
# 'Aichi Cancer Center Hospital ( Site 3101)'
# 'National Cancer Center Hospital East ( Site 3121)'
# 'National Hospital Organization Shikoku Cancer Center ( Site 3116)'
# 'Ehime University Hospital-Obstetrics and Gynecology ( Site 3158)'
# 'Kurume University Hospital ( Site 3105)'
# 'National Hospital Organization Hokkaido Cancer Center ( Site 3160)'
# 'Sapporo Kosei General Hospital ( Site 3172)'
# 'Sapporo Medical University Hospital ( Site 3113)'
# 'Hokkaido University Hospital ( Site 3165)'
# 'Hyogo Cancer Center ( Site 3131)'
# 'National Hospital Organization Himeji Medical Center ( Site 3111)'
# 'Kobe City Medical Center General Hospital ( Site 3144)'
# 'Hyogo Medical University Hospital ( Site 3100)'
# 'University of Tsukuba Hospital ( Site 3176)'
# 'Kanazawa University Hospital ( Site 3140)'
# 'Kagawa University Hospital ( Site 3171)'
# 'Kitasato University Hospital ( Site 3142)'
# 'Yokohama City University Hospital ( Site 3163)'
# 'Kanagawa cancer center ( Site 3137)'
# 'Yokosukakyosai ( Site 3150)'
# 'Miyagi Cancer Center ( Site 3122)'
# 'Tohoku University Hospital ( Site 3175)'
# 'Sendai Kousei Hospital ( Site 3115)'
# 'Nara Medical University Hospital ( Site 3110)'
# 'Kurashiki Central Hospital ( Site 3132)'
# 'University of the Ryukyus Hospital ( Site 3155)'
# 'Osaka Habikino Medical Center ( Site 3138)'
# 'Kansai Medical University Hospital ( Site 3126)'
# 'Kindai University Hospital- Osakasayama Campus ( Site 3166)'
# 'Kindai University Hospital ( Site 3102)'
# ('Kindai University Hospital- Osakasayama Campus-Department of '
#  'Gastroenterology and Hepatology ( Site')
# 'Osaka Rosai Hospital ( Site 3148)'
# 'Osaka University Hospital ( Site 3168)'
# 'Osaka Medical and Pharmaceutical University Hospital ( Site 3167)'
# 'Saitama Medical University International Medical Center ( Site 3118)'
# 'Saitama Cancer Center ( Site 3112)'
# 'Dokkyo Medical University - Koshigaya Hospital ( Site 3152)'
# 'Shizuoka Cancer Center ( Site 3128)'
# 'Jichi Medical University Hospital ( Site 3141)'
# 'Institute of Science Tokyo Hospital ( Site 3149)'
# 'Japanese Foundation for Cancer Research ( Site 3146)'
# 'Japanese Foundation for Cancer Research ( Site 3164)'
# 'Toranomon Hospital ( Site 3134)'
# 'Toranomon Hospital ( Site 3153)'
# 'Kyorin University Hospital ( Site 3147)'
# 'Kyorin University Hospital ( Site 3103)'
# 'Tokyo Medical University Hospital ( Site 3170)'
# 'National Hospital Organization Yamaguchi Ube Medical Center ( Site 3123)'
# 'Yamaguchi University Hospital ( Site 3114)'
# 'Chiba Cancer Center ( Site 3117)'
# 'National Hospital Organization Kyushu Medical Center ( Site 3136)'
# 'National Hospital Organization Kyushu Cancer Center ( Site 3169)'
# 'Kyushu University Hospital ( Site 3143)'
# 'Gifu University Hospital ( Site 3161)'
# 'Hiroshima City Hiroshima Citizens Hospital ( Site 3119)'
# 'Hiroshima University Hospital ( Site 3154)'
# 'Kochi Health Sciences Center ( Site 3145)'
# 'Niigata University Medical & Dental Hospital ( Site 3174)'
# 'Okayama University Hospital ( Site 3107)'
# 'Osaka City General Hospital ( Site 3125)'
# 'National Hospital Organization Osaka National Hospital ( Site 3162)'
# 'Osaka International Cancer Institute-Gynecologic Oncology ( Site 3129)'
# 'National Cancer Center Hospital ( Site 3130)'
# "St.Luke's International Hospital ( Site 3120)"
# 'The Jikei University Hospital-Obstetrics and Gynecology ( Site 3156)'
# 'Nippon Medical School Hospital ( Site 3139)'
# 'Tokyo Metropolitan Komagome Hospital ( Site 3133)'
# 'The Cancer Institute Hospital of JFCR ( Site 3108)'
# 'Keio University Hospital ( Site 3127)'
# 'Teikyo University Hospital ( Site 3104)'
# 'Wakayama Medical University Hospital ( Site 3124)'
# 'Chungbuk National University Hospital ( Site 0961)'
# 'Chonnam National University Hwasun Hospital-Hemato-Oncology ( Site 0959)'
# 'National Cancer Center ( Site 0955)'
# 'CHA Bundang Medical Center CHA University ( Site 0957)'
# 'Seoul National University Bundang Hospital ( Site 0951)'
# 'Asan Medical Center ( Site 0952)'
# 'Keimyung University Dongsan Hospital CRC room 1 ( Site 0960)'
# ('Chungnam national university hospital-Department of Internal Medicine ( Site '
#  '0958)')
# 'Korea University Anam Hospital ( Site 0956)'
# 'Seoul National University Hospital ( Site 0953)'
# 'Severance Hospital ( Site 0954)'
# 'Severance Hospital, Yonsei University Health System ( Site 0962)'
# 'Samsung Medical Center ( Site 0950)'
# 'Liepjas reionl slimnca ( Site 3851)'
# ('RIGA EAST UNIVERSITY HOSPITAL ,Oncology Centre of Latvia-Out-patient and Day '
#  'patient facility of Ch')
# 'Klaipeda University Hospital-Oncology chemotherapy ( Site 3302)'
# ('National Cancer Institute-Chemotherapy departament with day care unit ( Site '
#  '3301)')
# 'Vilniaus Universiteto Ligonine Santaros Klinikos ( Site 3300)'
# 'Hospital Tengku Ampuan Afzan ( Site 0627)'
# 'Gleneagles Penang ( Site 0625)'
# 'Pantai Hospital Kuala Lumpur ( Site 0628)'
# 'University Malaya Medical Centre ( Site 0626)'
# 'INSTITUTO NACIONAL DE CANCEROLOGIA ( Site 1102)'
# 'Avix Investigación Clinica, S.C.-Oncology ( Site 1104)'
# 'Oaxaca Site Management Organization ( Site 1106)'
# 'Medical Care and Research SA de CV ( Site 1103)'
# 'Oncare Viaducto Napoles ( Site 1107)'
# 'Radboud University Medical Center ( Site 1554)'
# 'Antoni van Leeuwenhoek Ziekenhuis ( Site 1551)'
# 'Amsterdam UMC, locatie VUmc ( Site 1555)'
# 'Erasmus MC ( Site 1553)'
# 'Universitair Medisch Centrum Groningen ( Site 1550)'
# 'Canterbury Regional Cancer & Blood Service ( Site 1500)'
# 'Waikato Hospital ( Site 1502)'
# 'Auckland City Hospital ( Site 1503)'
# 'Capital & Coast District Health Board - Wellington Hospital ( Site 1501)'
# 'Helse Bergen Haukeland universitetssykehus ( Site 1451)'
# 'Oslo Universitetssykehus Radiumhospitalet ( Site 1450)'
# ('Oslo Universitetssykehus Ullevål-Avdeling for kreftbehandling, Ullevål ( '
#  'Site 1452)')
# 'IPOR Instituto Peruano de Oncología & Radioterapia ( Site 0678)'
# 'INSTITUTO NACIONAL DE ENFERMEDADES NEOPLASICAS ( Site 0681)'
# 'Hospital Cayetano Heredia-Oncology ( Site 0675)'
# 'Makati Medical Center ( Site 1702)'
# 'Lung Center of the Philippines ( Site 1705)'
# 'St. Luke s Medical Center ( Site 1700)'
# ('Centrum Onkologii im. Prof. Franciszka Lukaszczyka-Ambulatorium '
#  'Chemioterapii ( Site 1612)')
# ('Powiatowe Centrum Zdrowia w Brzezinach Sp. z o. o. Oddział Dziennej '
#  'Chemioterapii ( Site 1611)')
# 'Instytut Centrum Zdrowia Matki Polki-Klinika Onkologii ( Site 1609)'
# ('Narodowy Instytut Onkologii im. Marii Sklodowskiej-Curie - Oddzial w '
#  'Krakowie ( Site 1608)')
# ('Narodowy Instytut Onkologii im. Marii Sklodowskiej-Curie - Panstwowy '
#  'Instytut Badawczy w Warszawie (')
# 'Wojskowy Instytut Medyczny-Klinika Onkologii ( Site 1606)'
# ('Opolskie Centrum Onkologii w Opolu im. prof. Tadeusza Kosza-Klinika '
#  'Onkologii z Odcinkiem Dziennym')
# 'Bialostockie Centrum Onkologii ( Site 1610)'
# 'Narodowy Instytut Onkologii - Oddzial w Gliwicach ( Site 1620)'
# 'Przychodnia Lekarska KOMED ( Site 1603)'
# 'Med-Polonia Sp. z o. o. ( Site 1605)'
# ('Szpital Kliniczny im. Przemienienia Panskiego Uniwersytetu Medycznego im. K. '
#  'Marcinkowskiego w Pozna')
# ('Szpital Wojewódzki im. Mikoaja Kopernika w Koszalinie-Oddzial Dzienny '
#  'Chemioterapii ( Site 1614)')
# 'Champalimaud Foundation ( Site 1751)'
# 'Unidade Local de Saude de Santa Maria - Hospital Pulido Valente ( Site 1750)'
# ('Instituto Português de Oncologia do Porto Francisco Gentil, EPE-Oncologia '
#  'Médica ( Site 1753)')
# 'Centro Hospitalar de Sao Joao - Hospital de Sao Joao ( Site 1752)'
# 'Ad-Vance Medical Research-Research ( Site 1151)'
# 'FDI Clinical Research ( Site 1152)'
# 'UPR Comprehensive Cancer Center ( Site 1150)'
# 'Spitalul Județean Sfântul Ioan cel Nou Suceava-Oncology ( Site 3550)'
# 'Altai Regional Clinical Oncology Center ( Site 1229)'
# ('Republican Clinical Oncology Dispensary of Republic of Bashkortostan ( Site '
#  '1204)')
# 'Bashkir State Medical University ( Site 1221)'
# 'Belgorod Oncology Dispensary ( Site 1213)'
# ("Regional Budgetary Healthcare Institution 'Ivanovo Regional Oncology "
#  "Dispensary'-Urology ( Site 1219")
# 'GBUZ LOKB ( Site 1218)'
# 'GBUZ LOKB-Oncology department #1 ( Site 1222)'
# 'Ogarev Mordovia State University ( Site 1206)'
# 'The National Medico-Surgical Center N.I. Pirogov ( Site 1225)'
# 'Russian Oncological Research Center n.a. N.N.Blokhin of MoH ( Site 1201)'
# 'N.N. Blokhin NMRCO ( Site 1209)'
# 'Russian Scientific Center of Roentgenoradiology ( Site 1215)'
# 'P. A. Hertsen Moscow Oncology Research Center ( Site 1214)'
# 'FSAI Treatment and Rehabilitation Centre of the MoH and SD of RF ( Site 1208)'
# ('Russian Scientific Research Institute of Hematology and Blood '
#  'Transfusion-Hematology ( Site 1224)')
# 'First Pavlov State Medical University of Saint Petersburg ( Site 1232)'
# 'Almazov National Medical Research Centre ( Site 1233)'
# ('N.N.Petrov Research Institute of Oncology-Department of Preclinical and '
#  'Clinical Research ( Site 121')
# ('Clinical Research Center of specialized types medical care-Oncology ( Site '
#  '1205)')
# 'EuroCityClinic ( Site 1230)'
# 'GBUZ SK Pyatigorsk Interdistrict Oncology dispensary ( Site 1223)'
# 'Republican Clinical Oncology Dispensary ( Site 1228)'
# ('Republican Clinical Oncology Dispensary of Tatarstan MoH named after '
#  'professor M.Z. Sigal ( Site 120')
# 'Tomsk Scientific Research Institute of Oncology ( Site 1227)'
# ('SAIH of the Tyumen region, Multidisciplinary Clinical Medical Center '
#  '"Medical town" ( Site 1220)')
# 'Udmurtian Republican Clinical Oncology Center ( Site 1212)'
# 'National Cancer Centre Singapore ( Site 2200)'
# 'National University Hospital-Haematology -Oncology Research Group ( Site 2201)'
# 'Wits Clinical Research ( Site 2002)'
# 'Wilgers Oncology Centre ( Site 2006)'
# 'LIFE GROENKLOOF-Mary Potter Cancer Centre ( Site 2005)'
# 'Sandton Oncology Medical Group (Pty) Ltd-Research ( Site 2004)'
# 'The Oncology Centre ( Site 2000)'
# 'Cape Town Oncology Trials ( Site 2007)'
# 'GVI Oncology ( Site 2008)'
# 'Hospital Universitario Virgen de la Victoria ( Site 0878)'
# 'Hospital Universitario Central de Asturias-Medical Oncology ( Site 0870)'
# 'Hospital Universitari Son Espases-Oncologia ( Site 0883)'
# 'Instituto Catalan de Oncologia ICO - Hospital Duran i Reynals ( Site 0860)'
# 'H. Marques de Valdecilla ( Site 0865)'
# 'Institut Catala d Oncologia Hospital Germans Trias i Pujol ( Site 0851)'
# 'Hospital Clinic de Barcelona ( Site 0852)'
# 'Hospital de la Santa Creu i Sant Pau-Oncología Médica ( Site 0862)'
# 'CHUS - Hospital Clinico Universitario-Servicio de Oncologia ( Site 0876)'
# 'Hospital Universitario Insular de Gran Canaria ( Site 0867)'
# 'Hospital Universitario Ramón y Cajal-Medical Oncology ( Site 0877)'
# 'Hospital Universitario Puerta de Hierro-Majadahonda ( Site 0861)'
# 'Hospital Universitario Quiron Madrid ( Site 0868)'
# 'H.R.U Malaga - Hospital General ( Site 0884)'
# 'Hospital Universitari Sant Joan de Reus-Oncology ( Site 0874)'
# 'Instituto Valenciano de Oncologia - IVO ( Site 0863)'
# 'Hospital Clinico de Valencia ( Site 0858)'
# 'Hospital General Universitario de Valencia ( Site 0854)'
# 'Hospital Arnau de Vilanova ( Site 0866)'
# 'Hospital Universitari i Politecnic La Fe ( Site 0875)'
# 'Hospital General Universitario de Alicante-Oncologia ( Site 0881)'
# 'Parc de Salut Mar - Hospital del Mar-Oncologia ( Site 0873)'
# 'H.U. Vall de Hebron ( Site 0850)'
# 'Complejo Hospitalario de Jaén-Servicio de Oncología Médica ( Site 0879)'
# 'Hospital Universitario Gregorio Maranon ( Site 0864)'
# 'Clinica Universitaria de Navarra ( Site 0855)'
# 'Hospital Clinico San Carlos ( Site 0857)'
# ('Hospital Universitario Fundación Jiménez Díaz-Oncology & Hematology ( Site '
#  '0871)')
# 'Hospital General Universitario 12 de Octubre ( Site 0856)'
# 'Hospital Universitario La Paz ( Site 0853)'
# ('Centro Integral Oncologico Clara Campal-Hospital HM Universitario '
#  'Sanchinarro-START Madrid, ( Site 0')
# ('Hospital Universitario Virgen Macarena-Unidad de Investigación Oncológica ( '
#  'Site 0880)')
# 'HOSPITAL UNIVERSITARIO VIRGEN DEL ROCIO-Medical Oncology ( Site 0872)'
# 'Hospital Universitario Virgen de Valme-Departamento de Oncologia ( Site 0882)'
# 'Hospital Clinico Universitario Lozano Blesa ( Site 0859)'
# 'Karolinska Universitetssjukhuset Solna ( Site 0802)'
# 'Blod och Tumorssjukdomar. Akademiska sjukhuset ( Site 0801)'
# 'Norrlands Universitetssjukhus ( Site 0800)'
# ('Sahlgrenska Universitetssjukhuset-Department of Oncology CTU Clinical Trial '
#  'Unit ( Site 0803)')
# 'University Hospital Basel ( Site 0752)'
# 'Hôpitaux Universitaires de Genève (HUG) ( Site 0753)'
# 'Universitaetsspital Zuerich ( Site 0750)'
# 'Chulalongkorn University ( Site 2363)'
# 'Ramathibodi Hospital ( Site 2364)'
# 'Faculty of Medicine Siriraj Hospital ( Site 2365)'
# 'Acibadem Altunizade Hospital-Oncology ( Site 1317)'
# 'Acibadem Adana Hospital-Pediatric Hematology-Oncology ( Site 1312)'
# ('Baskent University Dr. Turgut Noyan Research and Training Center-ONCOLOGY ( '
#  'Site 1307)')
# 'Ankara University Hospital Cebeci ( Site 1306)'
# 'Hacettepe Universitesi-oncology hospital ( Site 1304)'
# 'Ankara City Hospital-Medical Oncology ( Site 1311)'
# 'Baskent Universitesi Ankara Hastanesi ( Site 1303)'
# 'Akdeniz Universitesi Hastanesi-Medical Onkology ( Site 1318)'
# 'Memorial Antalya Hospital-Oncology ( Site 1315)'
# 'Trakya Universitesi Tip Fakultesi ( Site 1301)'
# 'Bezmialem Vakf Üniversitesi-Oncology ( Site 1308)'
# 'Istanbul University Capa Campus ( Site 1314)'
# 'Acıbadem Maslak Hastanesi-Medical Oncology ( Site 1321)'
# 'Istanbul Universitesi Cerrahpasa-Medical Oncology ( Site 1302)'
# ('TC Saglik Bakanligi Goztepe Prof. Dr. Suleyman Yalcin Sehir '
#  'Hastanesi-oncology ( Site 1316)')
# ('Marmara Universitesi Pendik Egitim Arastirma Hastanesi-Medical Oncology ( '
#  'Site 1305)')
# 'Ege Universitesi Tip Fakultesi Hastanesi ( Site 1300)'
# 'I.E.U. Medical Point Hastanesi-Oncology ( Site 1310)'
# 'Kocaeli Üniversitesi ( Site 1313)'
# 'Inonu Universitesi ( Site 1309)'
# ('Municipal Non-profit Enterprise "City Clinical Hospital #4" of Dnipro City '
#  'Council ( Site 3650)')
# ('MI Kryvyi Rih Oncology Dispensary of Dnipropetrovsk Regional-Chemotherapy '
#  'department ( Site 3657)')
# ('Communal Non-Commercial Enterprise "Prykarpatski Clinical Oncological '
#  'Center" of Ivano-Frankivsk Reg')
# 'MNPE Regional Center of Oncology ( Site 3665)'
# ('Private Enterprise Private Manufacturing Company Acinus-Medical and '
#  'Diagnostic Centre ( Site 3656)')
# ('National Cancer Institute-Department of Minimally Invasive and Endoscopic '
#  'Surgery, Interventional R')
# ('Municipal non-profit enterprise "Kyiv City Clinical Oncology Center" of '
#  'executive body of Kyiv City')
# ('Municipal institution of Lviv regional council Lviv Oncology-Chemotherapy ( '
#  'Site 3653)')
# 'Odessa Regional Oncology Center ( Site 3655)'
# ('Sumy regional clinical oncological dispensary-Oncothoracic department ( Site '
#  '3661)')
# ('Communal Noncommercial Enterprise "Podillia Regional Oncology Center Of '
#  'Vinnytsia Regional Council"')
# ('Transcarpathian Regional Clinical Oncology Center-Chemotherapy dept. ( Site '
#  '3652)')
# ('Municipal non-profit enterprise "Zaporizhzhia Regional Antitumor Center" '
#  'Zaporizhzhya Regional Counc')
# 'Aberdeen Royal Infirmary-Department of Oncology ( Site 0521)'
# 'Western General Hospital ( Site 0502)'
# 'The Christie ( Site 0516)'
# 'Weston Park Hospital ( Site 0519)'
# 'Mid Essex Hospitals Service Trust. Broomfield Hospital ( Site 0503)'
# 'The Beatson West of Scotland Cancer Centre ( Site 0506)'
# 'Royal Preston Hospital ( Site 0518)'
# 'Barts Health NHS Trust ( Site 0512)'
# 'University College London Hospital-Cancer Clinical Trials Unit ( Site 0520)'
# 'Royal Free Hospital ( Site 0507)'
# 'Royal Marsden Hospital ( Site 0505)'
# 'Sarah Cannon Research UK ( Site 0504)'
# 'Belfast City Hospital ( Site 0508)'
# 'Nottingham University Hospitals NHS Trust ( Site 0510)'
# 'St James University Hospital ( Site 0509)'
# 'The Royal Marsden NHS Foundation Trust. ( Site 0513)'
# 'New Cross Hospital-Department of Oncology ( Site 0517)'
# "Children's Hospital of Alabama"
# 'Providence Alaska Medical Center'
# "Arkansas Children's Hospital"
# 'Kaiser Permanente-Anaheim'
# 'Kaiser Permanente-Bellflower'
# 'Kaiser Permanente Downey Medical Center'
# 'Kaiser Permanente-Fontana'
# 'Loma Linda University Medical Center'
# "Children's Hospital Los Angeles"
# 'Kaiser Permanente Los Angeles Medical Center'
# "Valley Children's Hospital"
# "UCSF Benioff Children's Hospital Oakland"
# 'Kaiser Permanente-Oakland'
# "Children's Hospital of Orange County"
# "Lucile Packard Children's Hospital Stanford University"
# 'University of California Davis Comprehensive Cancer Center'
# 'Kaiser Permanente-San Diego Mission'
# "Rady Children's Hospital - San Diego"
# 'UCSF Medical Center-Mission Bay'
# "Children's Hospital Colorado"
# "Rocky Mountain Hospital for Children-Presbyterian Saint Luke's Medical Center"
# "Connecticut Children's Medical Center"
# 'Yale University'
# 'Alfred I duPont Hospital for Children'
# 'Kaiser Permanente-Capitol Hill Medical Center'
# 'MedStar Georgetown University Hospital'
# "Children's National Medical Center"
# "Golisano Children's Hospital of Southwest Florida"
# 'University of Florida Health Science Center - Gainesville'
# "Nemours Children's Clinic-Jacksonville"
# 'University of Miami Miller School of Medicine-Sylvester Cancer Center'
# "Nicklaus Children's Hospital"
# 'AdventHealth Orlando'
# 'Arnold Palmer Hospital for Children'
# "Nemours Children's Hospital"
# "Nemours Children's Clinic - Pensacola"
# "Johns Hopkins All Children's Hospital"
# "Children's Healthcare of Atlanta - Arthur M Blank Hospital"
# 'Straub Clinic and Hospital'
# 'Kaiser Permanente Moanalua Medical Center'
# 'Kapiolani Medical Center for Women and Children'
# "Saint Luke's Cancer Institute - Boise"
# "Lurie Children's Hospital-Chicago"
# 'University of Illinois'
# 'University of Chicago Comprehensive Cancer Center'
# 'Carle at The Riverfront'
# 'Carle Physician Group-Effingham'
# 'Carle Physician Group-Mattoon/Charleston'
# 'Saint Jude Midwest Affiliate'
# 'Carle Cancer Center'
# 'The Carle Foundation Hospital'
# 'Riley Hospital for Children'
# 'Ascension Saint Vincent Indianapolis Hospital'
# "Blank Children's Hospital"
# 'Iowa Methodist Medical Center'
# 'Iowa Lutheran Hospital'
# 'University of Iowa/Holden Comprehensive Cancer Center'
# 'University of Kentucky/Markey Cancer Center'
# "Norton Children's Hospital"
# "Children's Hospital New Orleans"
# 'Eastern Maine Medical Center'
# 'Lafayette Family Cancer Center-EMMC'
# 'Sinai Hospital of Baltimore'
# 'Johns Hopkins University/Sidney Kimmel Cancer Center'
# 'National Institutes of Health Clinical Center'
# 'Massachusetts General Hospital Cancer Center'
# 'Dana-Farber Cancer Institute'
# "C S Mott Children's Hospital"
# 'Wayne State University/Karmanos Cancer Institute'
# 'Henry Ford Health Saint John Hospital'
# 'Huron Medical Center PC'
# "Corewell Health Children's"
# "Children's Hospitals and Clinics of Minnesota - Minneapolis"
# 'University of Minnesota/Masonic Cancer Center'
# 'Mayo Clinic in Rochester'
# 'University of Mississippi Medical Center'
# 'Siteman Cancer Center at West County Hospital'
# "Children's Mercy Hospitals and Clinics"
# "Cardinal Glennon Children's Medical Center"
# 'Barnes-Jewish Hospital'
# 'Washington University School of Medicine'
# 'Siteman Cancer Center-South County'
# 'Mercy Hospital Saint Louis'
# 'Siteman Cancer Center at Saint Peters Hospital'
# "Children's Hospital and Medical Center of Omaha"
# 'University of Nebraska Medical Center'
# 'Comprehensive Cancer Centers of Nevada-Horizon Ridge'
# 'Sunrise Hospital and Medical Center'
# 'Alliance for Childhood Diseases/Cure 4 the Kids Foundation'
# 'Summerlin Hospital Medical Center'
# 'Hope Cancer Care of Nevada-Pahrump'
# 'Radiation Oncology Associates'
# 'Dartmouth Hitchcock Medical Center/Dartmouth Cancer Center'
# 'Hackensack University Medical Center'
# 'Morristown Medical Center'
# 'Rutgers Cancer Institute of New Jersey-Robert Wood Johnson University Hospital'
# 'Roswell Park Cancer Institute'
# 'NYU Langone Hospital - Long Island'
# "The Steven and Alexandra Cohen Children's Medical Center of New York"
# 'Laura and Isaac Perlmutter Cancer Center at NYU Langone'
# ('NYP/Columbia University Medical Center/Herbert Irving Comprehensive Cancer '
#  'Center')
# 'State University of New York Upstate Medical University'
# 'UNC Lineberger Comprehensive Cancer Center'
# 'Carolinas Medical Center/Levine Cancer Institute'
# 'Southeastern Medical Oncology Center-Clinton'
# 'Duke University Medical Center'
# 'Southeastern Medical Oncology Center-Goldsboro'
# 'Wayne Memorial Hospital'
# 'East Carolina University'
# 'Southeastern Medical Oncology Center-Jacksonville'
# "Cincinnati Children's Hospital Medical Center"
# 'Rainbow Babies and Childrens Hospital'
# 'MetroHealth Medical Center'
# 'Cleveland Clinic Foundation'
# "Nationwide Children's Hospital"
# "Dayton Children's Hospital"
# 'ProMedica Flower Hospital'
# "ProMedica Toledo Hospital/Russell J Ebeid Children's Hospital"
# 'University of Oklahoma Health Sciences Center'
# 'Oregon Health and Science University'
# "Children's Hospital of Philadelphia"
# "Children's Hospital of Pittsburgh of UPMC"
# 'Medical University of South Carolina'
# 'Saint Francis Hospital'
# "BI-LO Charities Children's Cancer Center"
# 'Saint Francis Cancer Center'
# 'East Tennessee Childrens Hospital'
# "Saint Jude Children's Research Hospital"
# "The Children's Hospital at TriStar Centennial"
# 'Medical City Dallas Hospital'
# 'UT Southwestern/Simmons Cancer Center-Dallas'
# "El Paso Children's Hospital"
# 'Texas Tech University Health Sciences Center-El Paso'
# 'Baylor College of Medicine/Dan L Duncan Comprehensive Cancer Center'
# "Children's Hospital of San Antonio"
# 'University of Vermont and State Agricultural College'
# 'University of Virginia Cancer Center'
# "Children's Hospital of The King's Daughters"
# "Seattle Children's Hospital"
# "Providence Sacred Heart Medical Center and Children's Hospital"
# 'Gundersen Lutheran Medical Center'
# 'University of Wisconsin Carbone Cancer Center - University Hospital'
# "Children's Hospital of Wisconsin"
# "Children's Hospital Orange County"
# 'Stanford University'
# 'University of California- San Francisco'
# ...
# 'Santa Rosa Medical Centers of Nevada / CCT Research'
# 'Circuit Clinical/Crystal Run'
# 'Randolph Medical Associates'
# 'University of North Carolina Kidney Center'
# 'Eastern Nephrology Associates / Greenville NC'
# 'Blue Sky, MD/ Lamond Family Medicine'
# 'Eastern Nephrology Associates - Kinston'
# 'Velocity Clinical Research, Cincinnati'
# 'Oakland Medical Center'
# 'Dunes Clinical Research LLC'
# 'DarSalud Care / LifeDOC Research'
# 'University of Tennessee Health Science Center'
# 'Office of Osvaldo A. Brusco, MD'
# 'Thyroid, Endocrinology, and Diabetes (TED) PA'
# 'DaVita Clinical Research- El Paso'
# 'Global Kidney Center'
# 'Victorium Clinical Research'
# 'North Texas Kidney Disease Associates, PLLC'
# 'Biopharma Informatic, LLC'
# 'Clinical Advancement Center, PLLC'
# 'University of Texas Health Science Center'
# 'Olympus Family Medicine'
# 'Salem VA Medical Center - Endocrinology'
# 'MultiCare Rockwood Clinic Diabetes & Endocrinology Center'
# 'CHU de Charleroi Hôpital civil'
# 'Onze-Lieve-Vrouwziekenhuis (OLVZ) - Campus Aalst'
# 'AZ St-Lucas Campus St-Lucas'
# 'UZ Gent'
# 'Regionaal ZH Jan Yperman Campus Mariaziekenhuis'
# 'AZ Groeninge Campus Kennedylaan'
# 'UZ Leuven Gasthuisberg'
# 'AZ Delta'
# 'LMC Manna Research - Calgary'
# 'Hamilton Medical Research Group'
# 'Clinical Research Solutions, Inc.'
# 'William Osler Health centre, Sakuara Medical'
# 'Bluewater Clinical Research Group'
# 'Sameh Fikry Professional Corporation'
# 'Recherche GCP Research'
# "Centre Hospitalier de l'Université de Montréal (CHUM)"
# 'LMC Clinical Research Inc. Montreal'
# 'Hospital of South West Jutland | Department of Endocrinology Research'
# ('Steno Diabetes Center Copenhagen | Herlev - Clinical and Translational '
#  'Research Department')
# 'Region Midtjylland | Regionshospitalet Godstrup - Nephrology Department'
# 'Bispebjerg Hospital - Hjerteafdeling'
# 'Hôpital François Mitterrand - Dijon'
# 'Center Hospitalier Michallon - Grenoble'
# 'Hôpital Edouard Herriot - Lyon Cedex'
# 'Many Locations'
# 'Hopital Carémeau - Nîmes'
# 'Hôpital Saint Joseph'
# 'St. Josefskrankenhaus'
# 'ClinPhenomics GmbH&Co. KG'
# 'Diabetologische Schwerpunkt Praxis Dortmund'
# 'Zentrum für Diabetologie und Ernährungsmedizin'
# 'Cardiologicum Pirna / Dresden-Seidnitz'
# 'Friedrich-Schiller-Uni. Jena'
# 'Charité Campus Benjamin Franklin (CBF)'
# 'Diabetes Zentrum Wandsbek'
# 'King George Hospital'
# 'All India Institute of Medical Sciences'
# 'Indraprastha Apollo Hospital'
# 'Mavani Dialysis & Kidney Center'
# 'Manipal Hospital'
# 'K.L.E.S. Dr. Prabhakar Kore Hospital & Medical Research Centre'
# 'Asian Kidney Hospital and Medical Centre'
# 'Eternal Heart Care Centre (EHCC) and Research Institute'
# 'G.S.V.M. Medical College'
# 'Institute of Post-Graduate Medical Education and Research'
# "Dr. Bantwal's Clinic"
# 'Bangalore Medical College & Research Institute'
# 'Government Kilpauk Medical College Hospital'
# 'Sriram Chandra Bhanj Medical College & Hospital'
# "Nizam's Institute of Medical Sciences (NIMS)"
# 'Sawami Man Singh (SMS) Medical College & Attached Hospitals'
# 'Government Medical College'
# 'Vinaya Hospital and Research Centre (A Unit of KIMS)'
# ('Seth Gordhandas Sunderdas Medical College (GSMC) - King Edward Memorial '
#  '(KEM) Hospital')
# 'Government Medical College and Hospital (GMCH) Nagpur'
# 'Max Super Speciality Hospital (MSSH) - Saket'
# 'Grant Medical Foundation - Ruby Hall Clinic (RHC)'
# 'Lifepoint Multispecialty Hospital'
# 'Krishna Institute Of Medical Science'
# 'Osmania General Hospital'
# 'Vedanta Kidney Care'
# 'HaEmek Medical Center | Internal Medicine C Department - Research Unit'
# 'Barzilai Medical Center | Department of Nephrology and Hypertension'
# 'Clalit Health | Soroka Medical Center - Internal Medicine Department'
# 'Edith Wolfson Medical Center | Internal Medicine Department'
# 'Hadassah University Medical Center (HUMC)'
# 'Health Corporation of Galilee Medical Center'
# 'Rabin Medical Center | Beilinson Hospital - Internal Medicine C Department'
# 'Health Corporation of the Ziv Medical Center (R.A.)'
# 'Azienda Ospedaliero Universitaria Parma - SC Nefrologia'
# 'ASL 4 Chiavarese'
# ('Azienda Socio Sanitaria Territoriale Papa Giovanni XXIII - Malattie '
#  'Endocrine e Diabetologia')
# "Fondazione IRCCS Ca' Granda Ospedale Maggiore Policlinico - Endocrinologia"
# ('Ospedale San Raffaele s.r.l. - Medicina Generale Indirizzo Diabetologico ed '
#  'Endocrino-Metabolico')
# ('Azienda Socio Sanitaria Territoriale Santi Paolo e Carlo_Ospedale S. Paolo - '
#  'Gestione integrata della malattia Diabetica')
# 'ASST Rhodense'
# ('Azienda Ospedaliero-Universitaria San Luigi Gonzaga - Malattie Metaboliche '
#  'Diabetologia')
# 'Casa Sollievo della Sofferenza - Endocrinologia'
# 'ATS Sardegna - ASSL Olbia'
# ('Azienda Ospedaliero Universitaria Pisana_Cisanello - Malattie Metaboliche e '
#  'Diabetologia')
# ('Azienda Ospedaliera Universitaria Integrata Verona_Borgo Roma - '
#  'Endocrinologia, Diabetologia e Malattie del Metabolismo')
# 'Università degli Studi "G. D\'Annunzio" di Chieti - Endocrinologia'
# 'Many Locations'
# 'Saiseikai Matsuyama Hospital'
# 'Fukuoka University Chikushi Hospital'
# 'Kokura Memorial Hospital'
# 'Hirohata Naika Clinic'
# 'Jiyugaoka Yamada Internal Medicine Clinic'
# 'Naka Kinen Clinic'
# 'Public Central Hospital of Matto Ishikawa | Clinical Trial Management Office'
# 'Fukui-ken Saiseikai Hospital'
# 'Social Medical Corporation the Chiyukai foundation Fukuoka Wajiro Hospital'
# 'Japanese Red Cross Kumamoto Hospital'
# 'Many Locations'
# 'Medical Corporation Taifukukai, Osaka Nishiumeda Clinic'
# 'Osaka General Medical Center'
# 'Soon Chun Hyang University Cheonan Hospital'
# 'Yonsei University Wonju Christian Hospital'
# 'Hallym University Sacred Heart Hospital'
# 'Seoul National University Bundang Hospital'
# "The Catholic University of Korea, Incheon St.Mary's Hospital"
# 'Seoul National University Hospital'
# 'Chung Nam National University Hospital'
# 'Hanyang University Guri Hospital'
# 'Korea University Ansan Hospital'
# 'Severance Hospital, Yonsei University Health System'
# 'Asan Medical Center'
# 'Kyung Hee University Hospital at Gangdong'
# 'Hallym University Kangnam Sacred Heart Hospital'
# 'Meander Medisch Centrum'
# 'Onze Lieve Vrouwe Gasthuis'
# 'Gelre Ziekenhuizen'
# 'Albert Schweitzer Ziekenhuis | Dordwijk - Cardiology Department'
# ('Gerencia de Gestion Integrada A Coruna | Department of Endocrinology and '
#  'Nutrition')
# ('Complejo Hospitalario Universitario de Ferrol | Hospital Naval - Unidad de '
#  'Hipertensión Arterial')
# 'Hospital Principe de Asturias'
# 'H. Costa del Sol (Marbella)'
# 'Hospital Vithas Sevilla | Endocrinology Department'
# "Ciutat Sanitaria i Universitaria de la Vall d'Hebron"
# 'Hospital Quironsalud Barcelona | Internal Medicine Department'
# ('Hospital Universitario Virgen de las Nieves | Servicio de Endocrinologia y '
#  'Nutricion')
# 'Hospital Clinico San Carlos'
# ('Universidad Autonoma de Madrid (UAM) - Facultad de Medicina - Hospital '
#  'Universitario Fundacion Jimenez Diaz (UAM-FJD)')
# ('Hospital Universitario Puerta de Hierro Majadahonda | Clinical Pharmacology '
#  'Department')
# ('Hospital Universitario Virgen de la Victoria | Unidad de Investigacion '
#  'Clinica - Endocrinology Department')
# 'Many Locations'
# 'Hospital Clínico Universitario de Valencia'
# 'Hospital Universitario Dr. Peset'
# 'Changhua Christian Hospital'
# 'Chang Gung Memorial Hospital Kaohsiung'
# 'Many Locations'
# 'Far Eastern Memorial Hospital | Nephrology Department'
# 'Taipei Medical University - Shuang Ho Hospital'
# 'China Medical University Hospital'
# 'Taichung Veterans General Hospital'
# 'Taipei Veterans General Hospital'
# "Children's Hospital of Alabama"
# 'University of Alabama at Birmingham Cancer Center'
# 'USA Health Strada Patient Care Center'
# 'Phoenix Childrens Hospital'
# 'Banner University Medical Center - Tucson'
# "Arkansas Children's Hospital"
# 'University of Arkansas for Medical Sciences'
# 'Kaiser Permanente Downey Medical Center'
# 'City of Hope Comprehensive Cancer Center'
# 'Loma Linda University Medical Center'
# "Miller Children's and Women's Hospital Long Beach"
# "Children's Hospital Los Angeles"
# 'Cedars Sinai Medical Center'
# "Valley Children's Hospital"
# "UCSF Benioff Children's Hospital Oakland"
# 'Kaiser Permanente-Oakland'
# "Children's Hospital of Orange County"
# "Lucile Packard Children's Hospital Stanford University"
# 'Sutter Medical Center Sacramento'
# 'University of California Davis Comprehensive Cancer Center'
# "Rady Children's Hospital - San Diego"
# 'UCSF Medical Center-Parnassus'
# 'UCSF Medical Center-Mission Bay'
# 'Lundquist Institute for Biomedical Innovation at Harbor-UCLA Medical Center'
# "Children's Hospital Colorado"
# "Rocky Mountain Hospital for Children-Presbyterian Saint Luke's Medical Center"
# "Connecticut Children's Medical Center"
# 'Yale University'
# 'Alfred I duPont Hospital for Children'
# 'MedStar Georgetown University Hospital'
# "Children's National Medical Center"
# 'Broward Health Medical Center'
# 'Lee Memorial Health System'
# "Golisano Children's Hospital of Southwest Florida"
# 'University of Florida Health Science Center - Gainesville'
# "Memorial Regional Hospital/Joe DiMaggio Children's Hospital"
# "Nemours Children's Clinic-Jacksonville"
# 'University of Miami Miller School of Medicine-Sylvester Cancer Center'
# "Nicklaus Children's Hospital"
# 'Miami Cancer Institute'
# 'AdventHealth Orlando'
# 'Arnold Palmer Hospital for Children'
# "Nemours Children's Clinic - Orlando"
# 'Orlando Health Cancer Institute'
# "Nemours Children's Hospital"
# "Nemours Children's Clinic - Pensacola"
# "Johns Hopkins All Children's Hospital"
# "Saint Joseph's Hospital/Children's Hospital-Tampa"
# "Saint Mary's Hospital"
# "Children's Healthcare of Atlanta - Arthur M Blank Hospital"
# 'Augusta University Medical Center'
# 'Memorial Health University Medical Center'
# 'University of Hawaii Cancer Center'
# 'Kapiolani Medical Center for Women and Children'
# 'Tripler Army Medical Center'
# "Saint Luke's Cancer Institute - Boise"
# "Lurie Children's Hospital-Chicago"
# 'University of Illinois'
# 'University of Chicago Comprehensive Cancer Center'
# 'Loyola University Medical Center'
# "Advocate Children's Hospital-Oak Lawn"
# "Advocate Children's Hospital-Park Ridge"
# 'Advocate Lutheran General Hospital'
# 'Saint Jude Midwest Affiliate'
# 'Southern Illinois University School of Medicine'
# 'Riley Hospital for Children'
# 'Ascension Saint Vincent Indianapolis Hospital'
# "Blank Children's Hospital"
# 'University of Iowa/Holden Comprehensive Cancer Center'
# 'University of Kansas Cancer Center'
# 'University of Kentucky/Markey Cancer Center'
# "Norton Children's Hospital"
# 'Tulane University School of Medicine'
# "Children's Hospital New Orleans"
# 'Ochsner Medical Center Jefferson'
# 'Eastern Maine Medical Center'
# "Maine Children's Cancer Program"
# 'University of Maryland/Greenebaum Cancer Center'
# 'Sinai Hospital of Baltimore'
# 'Johns Hopkins University/Sidney Kimmel Cancer Center'
# 'Walter Reed National Military Medical Center'
# 'Massachusetts General Hospital Cancer Center'
# 'Baystate Medical Center'
# 'UMass Memorial Medical Center - University Campus'
# "C S Mott Children's Hospital"
# 'Wayne State University/Karmanos Cancer Institute'
# 'Henry Ford Health Saint John Hospital'
# 'Michigan State University Clinical Center'
# 'Hurley Medical Center'
# "Corewell Health Grand Rapids Hospitals - Helen DeVos Children's Hospital"
# 'Bronson Methodist Hospital'
# 'Kalamazoo Center for Medical Studies'
# "Corewell Health Children's"
# "Children's Hospitals and Clinics of Minnesota - Minneapolis"
# 'University of Minnesota/Masonic Cancer Center'
# 'Mayo Clinic in Rochester'
# 'University of Mississippi Medical Center'
# "University of Missouri Children's Hospital"
# "Children's Mercy Hospitals and Clinics"
# 'Washington University School of Medicine'
# 'Mercy Hospital Saint Louis'
# "Children's Hospital and Medical Center of Omaha"
# 'University of Nebraska Medical Center'
# 'Alliance for Childhood Diseases/Cure 4 the Kids Foundation'
# 'Summerlin Hospital Medical Center'
# 'Nevada Cancer Research Foundation NCORP'
# 'Dartmouth Hitchcock Medical Center/Dartmouth Cancer Center'
# 'Hackensack University Medical Center'
# 'Saint Barnabas Medical Center'
# 'Morristown Medical Center'
# "Saint Peter's University Hospital"
# 'Rutgers Cancer Institute of New Jersey-Robert Wood Johnson University Hospital'
# 'Newark Beth Israel Medical Center'
# "Saint Joseph's Regional Medical Center"
# 'Overlook Hospital'
# 'University of New Mexico Cancer Center'
# 'Albany Medical Center'
# 'Montefiore Medical Center - Moses Campus'
# 'Brooklyn Hospital Center'
# 'Roswell Park Cancer Institute'
# 'NYU Langone Hospital - Long Island'
# "The Steven and Alexandra Cohen Children's Medical Center of New York"
# 'Laura and Isaac Perlmutter Cancer Center at NYU Langone'
# 'Mount Sinai Hospital'
# 'NYP/Weill Cornell Medical Center'
# 'University of Rochester'
# 'State University of New York Upstate Medical University'
# 'New York Medical College'
# 'Mission Hospital'
# 'UNC Lineberger Comprehensive Cancer Center'
# 'Carolinas Medical Center/Levine Cancer Institute'
# 'Novant Health Presbyterian Medical Center'
# 'Duke University Medical Center'
# 'East Carolina University'
# 'Wake Forest University Health Sciences'
# 'Sanford Broadway Medical Center'
# "Children's Hospital Medical Center of Akron"
# "Cincinnati Children's Hospital Medical Center"
# 'Rainbow Babies and Childrens Hospital'
# 'Cleveland Clinic Foundation'
# "Nationwide Children's Hospital"
# "Dayton Children's Hospital"
# "ProMedica Toledo Hospital/Russell J Ebeid Children's Hospital"
# "Mercy Children's Hospital"
# 'University of Oklahoma Health Sciences Center'
# 'Natalie Warren Bryant Cancer Center at Saint Francis'
# "Legacy Emanuel Children's Hospital"
# 'Legacy Emanuel Hospital and Health Center'
# 'Oregon Health and Science University'
# 'Lehigh Valley Hospital - Muhlenberg'
# 'Geisinger Medical Center'
# "Penn State Children's Hospital"
# "Children's Hospital of Philadelphia"
# "Saint Christopher's Hospital for Children"
# "Children's Hospital of Pittsburgh of UPMC"
# 'Medical University of South Carolina'
# 'Prisma Health Richland Hospital'
# "BI-LO Charities Children's Cancer Center"
# 'Greenville Cancer Treatment Center'
# 'Sanford USD Medical Center - Sioux Falls'
# "T C Thompson Children's Hospital"
# 'East Tennessee Childrens Hospital'
# 'Vanderbilt University/Ingram Cancer Center'
# 'Texas Tech University Health Sciences Center-Amarillo'
# "Dell Children's Medical Center of Central Texas"
# "Driscoll Children's Hospital"
# 'Medical City Dallas Hospital'
# 'UT Southwestern/Simmons Cancer Center-Dallas'
# "Cook Children's Medical Center"
# 'Baylor College of Medicine/Dan L Duncan Comprehensive Cancer Center'
# "Covenant Children's Hospital"
# "Children's Hospital of San Antonio"
# "Methodist Children's Hospital of South Texas"
# 'University of Texas Health Science Center at San Antonio'
# 'Scott and White Memorial Hospital'
# "Primary Children's Hospital"
# 'University of Vermont and State Agricultural College'
# 'University of Virginia Cancer Center'
# 'Inova Fairfax Hospital'
# "Children's Hospital of The King's Daughters"
# 'Virginia Commonwealth University/Massey Cancer Center'
# "Carilion Children's"
# "Seattle Children's Hospital"
# "Providence Sacred Heart Medical Center and Children's Hospital"
# "Mary Bridge Children's Hospital and Health Center"
# 'Madigan Army Medical Center'
# 'West Virginia University Charleston Division'
# 'Saint Vincent Hospital Cancer Center Green Bay'
# 'University of Wisconsin Carbone Cancer Center - University Hospital'
# 'Marshfield Medical Center-Marshfield'
# "Children's Hospital of Wisconsin"
# "Royal Brisbane and Women's Hospital"
# "Royal Children's Hospital-Brisbane"
# "Queensland Children's Hospital"
# "Women's and Children's Hospital-Adelaide"
# 'Monash Medical Center-Clayton Campus'
# "Royal Children's Hospital"
# 'Princess Margaret Hospital for Children'
# "Alberta Children's Hospital"
# 'University of Alberta Hospital'
# "British Columbia Children's Hospital"
# 'CancerCare Manitoba'
# 'Janeway Child Health Centre'
# 'IWK Health Centre'
# 'Kingston Health Sciences Centre'
# "Children's Hospital"
# "Children's Hospital of Eastern Ontario"
# 'Hospital for Sick Children'
# "The Montreal Children's Hospital of the MUHC"
# 'Allan Blair Cancer Centre'
# 'Saskatoon Cancer Centre'
# "Starship Children's Hospital"
# 'Christchurch Hospital'
# 'Swiss Pediatric Oncology Group - Geneva'
# 'Swiss Pediatric Oncology Group - Lausanne'

# %%
# Find documents where a principal investigator name contains "wu" (case-insensitive)
for trial in final_collection.find(
    {
        "principalInvestigator": {
            "$elemMatch": {"name": {"$regex": "wu", "$options": "i"}}
        }
    }
):
    # Loop through each principal investigator in the trial
    for investigator in trial.get("principalInvestigator", []):
        # Loop through each location in the trial and print investigator name with facility
        for location in trial.get("locations", []):
            pprint.pprint(
                (investigator["name"], location.get("facility", "No Facility"))
            )
# Out:
# ('Ivan Wu', 'University of Minnesota')
# ('Abraham Wu, MD', 'Memorial Sloan Kettering Cancer Center')

# %%
final_collection.count_documents({"endDate": {"$lt": "2024-11-11"}})
# Out:
# 179

# %%
final_collection.count_documents({"endDate": {"$gte": "2024-11-11"}})
# Out:
# 440

# %%
number = final_collection.count_documents({"endDate": "NA"})

print(number)

for trial in final_collection.find({"endDate": "NA"}):
    pprint.pprint(trial["trialId"])
# Out:
# 4
# 'NCT00233272'
# 'NCT06649669'
# 'NCT00342888'
# 'NCT06597747'

# %%
final_collection.find_one({"trialId": "NCT06649669"})
# Out:
# {'_id': ObjectId('673285464dd83486d5a4d3f5'),
#  'trialId': 'NCT06649669',
#  'title': '[Trial of device that is not approved or cleared by the U.S. FDA]',
#  'startDate': 'NA',
#  'endDate': 'NA',
#  'phase': 'Other',
#  'principalInvestigator': [],
#  'locations': [],
#  'eligibilityCriteria': ''}

# %%
for trial in final_collection.find(
    {"title": "[Trial of device that is not approved or cleared by the U.S. FDA]"}
):
    # Print the trialId directly
    pprint.pprint(trial.get("trialId"))
# Out:
# 'NCT06649669'
# 'NCT06597747'

# %%
for trial in final_collection.find(
    {"trialId": {"$in": ["NCT06561048", "NCT06399289", "NCT06415344"]}}
):

    print("trialId:", trial.get("trialId"))

    print("eligibilityCriteria:", trial.get("eligibilityCriteria"))

    print("\n")
# Out:
# trialId: NCT06561048
# eligibilityCriteria: Inclusion Criteria:
#
#   1. Adult participants ≥18 years of age on the day of signing the informed consent form.
#
#   2. Eastern Cooperative Oncology Group (ECOG) Performance Status of 0 to 2.
#
#   3. Histologically confirmed PTCL-NOS, FHTCLs or sALCL per The International Consensus
#      Classification of Mature Lymphoid Neoplasms.
#
#   4. Progressed on, be refractory to, relapsed, or intolerant to standard therapy for
#      their cancer. At least 1 but not more than 3 prior systemic therapies.
#
#   5. Fluorodeoxyglucose-avid disease by positron emission tomography and measurable
#      disease of at least 1.5 cm by computed tomography, as assessed by the site
#      radiologist.
#
#   6. Life expectancy >12 weeks.
#
#   7. Adequate organ function as determined by:
#
#        -  Absolute neutrophil count ≥ 1.0×10^9/L (1000/mm3) (without receiving
#           granulocyte-colony stimulating factor)
#
#        -  Platelet count ≥ 50×10^9/L (without transfusion)
#
#        -  Hemoglobin ≥ 9.0 g/dL, without packed red blood cell transfusion within the
#           last 1 week of starting study drug
#
#        -  Prothrombin time international normalized ratio and partial thromboplastin time
#           ≤1.5 × upper limit of normal (ULN), unless participant is receiving
#           anticoagulant therapy and prothrombin time or activated partial thromboplastin
#           time is within therapeutic range of intended use of anticoagulants
#
#        -  Calculated creatinine clearance (CrCl) according to Cockcroft-Gault formula and
#           based on ideal body weight or 24-hour urine CrCl ≥ 50 mL/minute
#
#        -  Total bilirubin ≤ 1.5 × ULN or direct bilirubin ≤ ULN for participants with
#           total bilirubin levels > 1.5 × ULN. For participants with Gilbert's disease: ≤
#           3.0 mg/dL or discussion with the Medical Monitor
#
#        -  Aspartate aminotransferase and alanine transaminase ≤ 2.5 × ULN (≤ 5 × ULN for
#           participants with liver metastases)
#
#        -  Serum albumin > 2.5 g/dL
#
#        -  Serum calcium < 12 mg/dL or corrected serum calcium < ULN
#
#   8. Female participants of childbearing potential who are sexually active with a
#      non-sterilized male partner must agree to use at least 1 highly effective method of
#      contraception from the time of screening and must agree to continue using such
#      precautions for 120 days after the last dose of study drug for participants who
#      receive soquelitinib, or 6 months after the last dose for participants who receive
#      either belinostat or pralatrexate.
#
#   9. Non-sterilized males who are sexually active with a female partner of childbearing
#      potential must use a condom plus spermicide from Day 1 through 120 days after the
#      last dose of study drug.
#
# Exclusion Criteria:
#
#   1. Participants who have T-cell lymphoma with active central nervous system
#      involvement.
#
#   2. Any significant medical condition, laboratory abnormality, or psychiatric illness
#      that would prevent the participant from participating in the study.
#
#   3. Any condition that confounds the ability to interpret data from the study.
#
#   4. Any active infection requiring IV therapy.
#
#   5. History of invasive prior malignancy that required systemic therapy within last 3
#      years.
#
#   6. Known to be positive for HIV, or positive test for chronic hepatitis B virus (HBV)
#      infection (defined as positive hepatitis B surface antigen [HBsAg]) or positive test
#      for hepatitis C antibody.
#
#   7. Monoclonal antibody therapy for cancer, radiotherapy, or chemotherapy within 3 weeks
#      and targeted therapy within 2 weeks prior to the first dose of study treatment.
#
#   8. History of allogeneic hematopoietic stem cell transplantation.
#
#   9. Candidate for hematopoietic stem cell transplantation at screening.
#
#  10. History of progressive disease within 6 months of autologous hematopoietic stem cell
#      transplantation.
#
#  11. Females who are pregnant, lactating, or intend to become pregnant during their
#      participation in the study, starting with the screening visit through 6 months after
#      the last dose of study treatment.
#
#
# trialId: NCT06399289
# eligibilityCriteria: Inclusion Criteria:
#
#   -  Male Chinese subjects aged ≤ 70 years
#
#   -  Subjects with documented severe or moderately severe hemophilia B (FIX activity of ≤
#      2%)
#
#   -  Subjects have received FIX products for ≥ 150 exposure days (EDs) (subjects aged ≥ 6
#      years) or ≥ 50 EDs (subjects aged < 6 years)
#
#   -  Subjects have no confirmed prior history of FIX inhibitor formation
#
# Exclusion Criteria:
#
#   -  Known hypersensitivity (allergic reaction or anaphylaxis) to any FIX product or
#      hamster protein.
#
#   -  Known congenital or acquired coagulation disorder other than congenital FIX
#      deficiency.
#
#   -  Currently receiving intravenous (IV) immunomodulating agents such as immunoglobulin
#      or chronic systemic corticosteroid treatment.
#
#   -  Currently receiving a long-acting recombinant FIX treatment such as coagulation
#      factor IX (recombinant), Fc fusion protein (Alprolix®).
#
#   -  Use of traditional or herbal Chinese medicine(s) with an impact on hemophilia,
#      including coagulation, within 28 days before Day 1 and / or refusal to abstain from
#      these during the study until the end of the subject's participation in the study.
#
#
# trialId: NCT06415344
# eligibilityCriteria: Inclusion Criteria:
#
#   -  Signed informed consent from parent(s) or legal guardian(s).
#
#   -  Prior participation in a clinical trial with GTX-102; the timing for the roll-over
#      into this study from a prior GTX-102 study is based on the Investigator and
#      Ultragenyx Medical Monitor's approval.
#
#   -  From the time of informed consent through the end of the study and for at least 6
#      months after the final dose of GTX-102, females of childbearing potential who are
#      sexually active must use highly effective contraception or abstinence. Males are
#      able to participate if they agree to remain abstinent (refrain from heterosexual
#      intercourse) or use acceptable contraceptive methods during the study and for at
#      least 3 months after the final dose of GTX-102.
#
# Exclusion Criteria:
#
#   -  Known hypersensitivity to GTX-102 or its excipients that, in the judgment of the
#      Investigator, places the subject at increased risk for adverse effects.
#
#   -  Pregnant or breastfeeding or planning to become pregnant (self or partner) at any
#      time during the study

# %% [markdown]
# ## Extract info from the eligibilityCriteria field and store them in MongoDB

# %%
# import openai
from openai import OpenAI

# %%
from config import api_key

# %%
client = OpenAI(api_key=api_key)

# %%
# Minimize API Calls by Using Local Processing First
def preprocess_text(eligibility_text):
    # Extract the "Inclusion Criteria" section using regex or keyword-based filtering
    match = re.search(
        r"Inclusion Criteria:.*?(Exclusion Criteria:|$)",
        eligibility_text,
        re.DOTALL | re.IGNORECASE,
    )
    if match:
        return match.group(0)
    return eligibility_text

# %%
def LLM_model(eligibility_text):
    # Construct a prompt to extract diseases/conditions only from inclusion criteria
    prompt = f"""
    Extract all diseases, conditions, or criteria related to medical treatments or exposures.

    Important:
    - Include diseases, conditions, demographic criteria (e.g., gender, age, ethnicity), and medical treatments or exposures (e.g., "FIX products exposure") while excluding numeric thresholds or detailed qualifiers.
    - Combine demographic criteria into a single entry
    - Retain contextual information or negations when they are part of the condition (e.g., "no FIX inhibitor formation").
    - Ensure the output is concise and excludes extra text or formatting.
    
    Eligibility Criteria: {eligibility_text}
    
    Please list only the diseases or conditions without any extra text.
    """

    # Call the OpenAI API with the prompt
    response = client.chat.completions.create(
        model="gpt-4o-mini",
        messages=[
            {"role": "system", "content": "You're a helpful clinical trial assistant"},
            {"role": "user", "content": prompt},
        ],
        max_tokens=100,
        temperature=0,
    )

    # Extract the response text containing the diseases/conditions
    extracted_conditions = response.choices[0].message.content
    return extracted_conditions

# %%
def flatten(arg):
    if not isinstance(arg, list):  # if not list
        return [arg]
    return [x for sub in arg for x in flatten(sub)]

# %%
def get_nested_value(data, keys2):
    keys = keys2.split(".")
    for key in keys:
        if isinstance(data, dict):
            data = data.get(key)
        elif isinstance(data, list):
            valuelist = []
            for ele in data:
                valuelist.append(ele.get(key))
            data = flatten(valuelist)
    return data

# %%
def add_dict_pair(opkey, opvalue, results_dict):
    if opkey not in results_dict:
        results_dict[opkey] = []
    results_dict[opkey].append(opvalue)

# %%
# Function to process trials and extract conditions
def extract_info(collection, field, content):
    results_dict = {}

    for trial in collection.find({}):
        opkey = get_nested_value(trial, field)
        opvalue = get_nested_value(trial, content)
        if content == "eligibilityCriteria":
            inclusion_text = preprocess_text(opvalue)
            opvalue = LLM_model(inclusion_text)
        if isinstance(opkey, list):
            for opkeysingle in opkey:
                add_dict_pair(opkeysingle, opvalue, results_dict)

        else:
            add_dict_pair(opkey, opvalue, results_dict)

    return results_dict

# %%
def store_in_collection(field, content, results_dict, collection, batch_size=100):
    operations = []

    for key, value in results_dict.items():
        operations.append(
            UpdateOne(
                {field: key},
                {"$set": {content: value}},
            )
        )

        if len(operations) == batch_size:
            collection.bulk_write(operations)
            operations = []

    if operations:
        collection.bulk_write(operations)

# %%
results_dict = extract_info(final_collection, "trialId", "eligibilityCriteria")

# Could also load the results_dict for reproducibility
# with open("results_dict.pkl", "rb") as f:
#     results_dict = pickle.load(f)


store_in_collection("trialId", "extractedDiseases", results_dict, final_collection)

# %% [markdown]
# To add other transformation steps (link_principal_investigator):

# %%
extract_info(final_collection, "principalInvestigator.name", "trialId")
# Out:
# {'Leonard A Bradshaw, PhD': ['NCT03176927'],
#  'John Heinzerling, MD': ['NCT04060927'],
#  'Keith Choate, MD, PhD': ['NCT06651489'],
#  'Marie Roguski, MD MPH': ['NCT06649591'],
#  'Christoper Barker, MD': ['NCT04792073'],
#  'Nathan Congdon, MD': ['NCT06065631'],
#  'Ock K Chun, PhD': ['NCT04431960'],
#  'Howard M Katzenstein': ['NCT00980460'],
#  'Claus Cursiefen, Prof. Dr.': ['NCT05870566'],
#  'Erica C. Kaye, MD, MPH': ['NCT05116566'],
#  'Anna De Simoni, PhD': ['NCT05829265'],
#  'William Gleason, OD': ['NCT05285527', 'NCT05285553'],
#  'Natalie Lockney, MD': ['NCT05156060'],
#  'Kent Nilsson, MD': ['NCT05883631'],
#  'Lucas Boersma, Prof. MD.': ['NCT05883631'],
#  'Anxo Fernandez-Ferreiro, PhD': ['NCT04756466'],
#  'Olcay Aycicek, Asist Prof': ['NCT06650774'],
#  'Pianosi Paolo, MD': ['NCT05025774'],
#  'John B. Liao': ['NCT04387227'],
#  'Federico Linassi, MD': ['NCT03774420'],
#  'Xiaojing Hu, PhD': ['NCT06650020', 'NCT06550440'],
#  'Laurie E Cutting, PhD': ['NCT03713125'],
#  'Audrey Harkness, PhD': ['NCT06432725'],
#  'John Villano, MD, PhD': ['NCT04964960'],
#  'Vikky Makker, MD': ['NCT04513665'],
#  'Helge Möllmann': ['NCT03752866'],
#  'Frank A Bucci, MD': ['NCT06016231'],
#  'Li Huo, MD': ['NCT06649682'],
#  'Alaine E Reschke-Hernandez, PhD': ['NCT06219148'],
#  'Allison Gibson, PhD': ['NCT06219148'],
#  'Alaine E. Reschke-Hernandez, PhD': ['NCT06605157'],
#  'Luigi Ferrucci, M.D.': ['NCT00233272'],
#  'Holly Wyatt, MD': ['NCT04745572'],
#  'Marianna Koczywas': ['NCT02535312'],
#  'Craig Crandall, PhD': ['NCT06582680'],
#  'Srivandana Akshintala': ['NCT02867592'],
#  'Alain SAAD': ['NCT06013462'],
#  'Miae OH': ['NCT06650644'],
#  'Hirva Mamdani, MD': ['NCT05903092'],
#  'Marina Caskey, MD': ['NCT05245292'],
#  'Manali I Patel, MD MPH MS': ['NCT04463992'],
#  'Dustin C Lee, PhD': ['NCT06351540'],
#  'Summer Hanson, MD, PhD, FACS': ['NCT06650592'],
#  'Rebecca Sartini, DNP': ['NCT05127044'],
#  'Anne-Sophie Brazeau, PhD': ['NCT05910840'],
#  'Kristie A Blum': ['NCT01286272'],
#  'Mohamed Hamdy, Lecturer': ['NCT06650280'],
#  'Kelli J England, PhD': ['NCT06650462'],
#  'Megan Marie Kelly, PhD MS': ['NCT04567680'],
#  'Kathryn Glaser': ['NCT04754529'],
#  'Hrishikesh Chakraborty': ['NCT05966129', 'NCT05966142', 'NCT05966155'],
#  'Mark Lazarev, MD': ['NCT01169194'],
#  'Anna H. Grummon, PhD': ['NCT06648226'],
#  'Carolyn Bramante, MD': ['NCT04837586'],
#  'Afton Hassett': ['NCT06567886'],
#  'Kevin Hall, Ph.D.': ['NCT06325722'],
#  'Chaosu Hu': ['NCT06437522', 'NCT06006169'],
#  'Dongmei Ji': ['NCT06437522', 'NCT06006169'],
#  'Peter Pellegrino, MD': ['NCT06480786'],
#  'Heather Kaplan, MD, MSCE': ['NCT05898022'],
#  'Anna Maria Hibbs, MD, MSCE': ['NCT05898022'],
#  'Jean-Philippe Drouin-Chartier, PhD': ['NCT06389825'],
#  'Jessica Ansari, MD, MS': ['NCT06650930'],
#  'Annette DeVito Dabbs, PhD': ['NCT03728257'],
#  'Yash B. Joshi, MD PhD': ['NCT04395157'],
#  'Lars O Cardell, Professor': ['NCT06061848'],
#  'Sumit Gupta': ['NCT03914625'],
#  'Imran K Niazi, MD': ['NCT00944125'],
#  'Puyu Su, Professor': ['NCT06247930'],
#  'Pinghong Zhou, MD, PhD': ['NCT06649825'],
#  'Chao-Chi Ho, MD, PhD': ['NCT05970848'],
#  'Milos Velinovic, MD, PhD': ['NCT06650839'],
#  'Danijela Trifunovic-Zamklar, MD, PhD': ['NCT06650839'],
#  'Edelgard Lindhoff-Last, Professor': ['NCT06650826'],
#  'Sean M Oser, MD, MPH': ['NCT05168657'],
#  'Tamara K Oser, MD': ['NCT05168657'],
#  'Lily A Brown, PhD': ['NCT06234969'],
#  'Jan Reidar Stiegler, PhD': ['NCT04690946'],
#  'Ajay Premkumar, MD': ['NCT05859269'],
#  'Stefan Leucht, MD': ['NCT01029769'],
#  'Lora Giangregorio, PhD': ['NCT06650410'],
#  'Kevin Krull, PhD': ['NCT05480904'],
#  'Etta Pisano': ['NCT03233191'],
#  'Wilson Z Ray, MD': ['NCT03296592'],
#  'Carrie L Pistenmaa, MD, MS': ['NCT05567562'],
#  'Lori J. Wirth, MD': ['NCT05668962'],
#  'Lisa S. Chow, MD': ['NCT02150889'],
#  'Michelle L Hermiston': ['NCT05828069'],
#  'Kiminori Kimura, MD': ['NCT04688034'],
#  'Muhammad Zarak Awais, MBBS': ['NCT06651034'],
#  'David R Smith, Ph.D.': ['NCT04633434'],
#  'Mark B Geyer, MD': ['NCT04512716'],
#  'Ruth Blanco Rojo, PhD': ['NCT06651424'],
#  'Frederique Paulus, prof. dr.': ['NCT06649734'],
#  'Michael Koenigs, PhD': ['NCT06162624'],
#  'Hamiyet Kızıl, Phd RN': ['NCT06649617'],
#  'Brian Vickery, MD': ['NCT05621317'],
#  'Edward G Clark, MD MSc FRCPC': ['NCT04705896'],
#  'Jennifer Johansson, MS': ['NCT05267639'],
#  'James I Geller': ['NCT03595124'],
#  'Amanda Rao, PhD': ['NCT06006416'],
#  'rana ka Abuzaid, orthodontist': ['NCT06631235'],
#  'Carlos A Zarate, M.D.': ['NCT03065335'],
#  'Margaret MacMillan': ['NCT05735717'],
#  'Martin Muckley, FRCPI': ['NCT04587635'],
#  'Xavier MOISSET': ['NCT06426316'],
#  'Alexis MOSCA, MD': ['NCT06651216'],
#  'Christopher J Melani': ['NCT06649812'],
#  'Eugenio Fernandez': ['NCT05071846'],
#  'Anders Thorell, Professor': ['NCT04182412'],
#  'Johann Bauersachs, Prof. Dr.': ['NCT05350969'],
#  'Shira Goldenberg, PhD': ['NCT06468046'],
#  'Werner Bischoff, MD': ['NCT03909867'],
#  'Sherman Holtan, MD': ['NCT05123040'],
#  'Carla S Stover, Ph.D.': ['NCT06650267'],
#  'Rachel Freedman, MD MPH': ['NCT03587740'],
#  'Gareth R Dutton, PhD': ['NCT02736669'],
#  'Qianyu Zhuang, Professor': ['NCT06279468'],
#  'Emily G McDonald, MD MSC': ['NCT06650501'],
#  'Zosia Piotrowska, MD': ['NCT03239340'],
#  "Mark O'Hara, MD": ['NCT03323944'],
#  'Abdusalom Abdurakhmanov, MD': ['NCT06150872'],
#  'Henrik Grönberg, MD, PhD': ['NCT04583072'],
#  'Matthew Tennant, MD, FRCSC': ['NCT06649604'],
#  'Paolo F. Caimi, MD': ['NCT05312801'],
#  'Channing Paller, MD': ['NCT02452008'],
#  'Aaron Folsom, MD, MPH': ['NCT00005504'],
#  'Guido Beldi': ['NCT05775341'],
#  'Graham Foster, MBBS': ['NCT05248919'],
#  'Chaohui Yu, Doctor': ['NCT06650319'],
#  'Patrick J Smith, PhD, MPH': ['NCT05997316'],
#  'Drew Sayer, PhD': ['NCT04014296'],
#  'Sümeyye Akçay, PT': ['NCT06210516'],
#  'Lai Wei': ['NCT06123858'],
#  'Kristen Kelley': ['NCT06590558'],
#  'Ghazala Saleem, EdD': ['NCT05762796'],
#  'Vaishalee Kenkre, MD': ['NCT05551936'],
#  'Tokiko Hamasaki, PhD': ['NCT06401317'],
#  'Stephanie Lheureux': ['NCT03367741'],
#  'Rianne Oosterkamp, MD': ['NCT01898117'],
#  'Marleen Kok, MD': ['NCT01898117'],
#  'Cédric LAMIREL, MD': ['NCT05264818'],
#  'Jin H. Han, MD': ['NCT03733418'],
#  'Bouthaina S Dabaja': ['NCT05035706'],
#  'Dahui Wang, MD-PhD': ['NCT04527406'],
#  'JoAnna K Leyenaar, MD, PhD': ['NCT04192799'],
#  'Eva Szigethy': ['NCT05159713'],
#  'Ecaterina E Dumbrava': ['NCT03725436'],
#  'Prof Andrew Prendergast, DPhil MRCPCH': ['NCT05419336'],
#  'Kubra Alpay, PhD': ['NCT06646536'],
#  'TBD TBD': ['NCT04374136'],
#  'Ralph DeFronzo, MD': ['NCT04300049'],
#  'Thorsten Kahnt, Ph.D.': ['NCT05707806'],
#  'Stephen Fremes, MD,MSc,FRCSC': ['NCT05427370'],
#  'Mario Gaudino, MD,PhD': ['NCT05427370'],
#  'Jean L Rouleau, MD,PhD': ['NCT05427370'],
#  'Guillaume Maquis-Gravel, MD,MSc': ['NCT05427370'],
#  'Jonatan Ruiz Ruiz, Dr.': ['NCT06650670'],
#  'Rona Yaegar, MD': ['NCT03843775'],
#  'Deepa G Manwani, M.D': ['NCT01757418'],
#  'Wolfgang Kemmler, PhD': ['NCT06642350'],
#  'Maura L Gillison': ['NCT04533750'],
#  'Guliano Cerulli, MD': ['NCT06571955'],
#  'Ihsan Salloum, MD': ['NCT03265808'],
#  'Valérie BENOIT': ['NCT06357208'],
#  'Andreas Peyrl, MD': ['NCT01356290'],
#  'Andreas Trojan, Prof. Dr. med.': ['NCT05425550'],
#  'Peter Fasching, Prof. Dr. med.': ['NCT05425550'],
#  'Erika Matos, PhD': ['NCT06650423'],
#  'Principal Investigator': ['NCT06650202'],
#  'Simon Wernhart, MD': ['NCT06650995'],
#  'Ricardo Espinoza, MD': ['NCT06649981'],
#  'Diwakar Davar, MD, M.Sc': ['NCT04401995'],
#  'Murielle Roussel, MD': ['NCT06649695'],
#  'Funda Meric-Bernstam': ['NCT06364410'],
#  'Martin K. Kankam, MD, PhD, MPH, FAPCR': ['NCT06617546'],
#  'Vatinee Bunya, MD': ['NCT05056012'],
#  'Kerri Winters-Stone': ['NCT06049355'],
#  'Jing Chen, PhD': ['NCT05329155'],
#  'Sophie Susen, MD, Professor': ['NCT06651255'],
#  'James Yu': ['NCT06111781'],
#  'Alice L Yu': ['NCT00026312'],
#  'Brian Helfand, M.D.': ['NCT06604442'],
#  'Liqun Jiao, MD': ['NCT06047964'],
#  'Yan Ma, MD': ['NCT06047964'],
#  'Kenneth Offit, MD, MPH': ['NCT05420064'],
#  'Paola Azucena Alvarado Pelayo, Bachelor': ['NCT06576479'],
#  'Damien GUINDOLET': ['NCT05400590'],
#  'Kristen Lindgren, PhD, ABPP': ['NCT06648395'],
#  'Michele Bedard-Gilligan, PhD': ['NCT06648395'],
#  'Pamela Samson, M.D., MPHS': ['NCT05427214'],
#  'Vanessa Meier-Stephenson, MD, PhD': ['NCT04882514'],
#  'Michael Good, MD, PhD': ['NCT04882514'],
#  'Michael Houghton, PhD': ['NCT04882514'],
#  'Lorne Tyrrell, MD PhD': ['NCT04882514'],
#  'Michael Hawkes, MD, PhD': ['NCT04882514'],
#  'Andreas M Fritzen, Associate Professor': ['NCT06623032'],
#  'Sara Ramel, MD': ['NCT03479515'],
#  'Emily A Kringle, PhD, OTR/L': ['NCT05964400'],
#  'Megan Gunnar, PhD': ['NCT05537259'],
#  'Laure Joseph, M.D.': ['NCT06650059'],
#  'Savannah Partridge': ['NCT03607552'],
#  'Vicky Makker, MD': ['NCT03285152'],
#  'Motolani Adedipe, PhD, DPh, MS': ['NCT06651359'],
#  'Kenneth W. Merrell, MD': ['NCT03902600'],
#  'Krishan R. Jethwa, MD': ['NCT03902600'],
#  'Terence T. Sio, MD, MS': ['NCT03902600'],
#  'Jonathan B. Bricker': ['NCT04308759'],
#  'Helen Storr, PhD': ['NCT05829252'],
#  'Jieer Ying, MD': ['NCT06650332'],
#  'Ann Smeets, MD,PhD': ['NCT06415032'],
#  'DINO TIKVESA, MD': ['NCT06650137'],
#  'Jennifer Ellis, Ph.D.': ['NCT05546515'],
#  'Reza Hejazi, MD': ['NCT04938102'],
#  'David Kim, DDS, DMSc': ['NCT06651502'],
#  'Regina Rabinovich': ['NCT04966702'],
#  'Carlos Chaccour': ['NCT04966702'],
#  'Hans-Christoph Friederich, Prof. Dr.': ['NCT06651164'],
#  'Xiaoli Nan': ['NCT05959564'],
#  'Julie Heimbach': ['NCT06649864'],
#  'Jeffrey R Wozniak, Ph.D.': ['NCT05456321'],
#  'Adeyemi Ogunleye, MD': ['NCT06649890'],
#  'Hannah Linden': ['NCT04692103'],
#  'Shounak Majumder, M.D.': ['NCT04247503', 'NCT00835133'],
#  'Sacha NAHON ESTEVE': ['NCT05051384'],
#  'John A Sauceda, PhD': ['NCT03668379'],
#  'Saumil Gandhi, MD': ['NCT03707938'],
#  'Jeffrey M Jacobson': ['NCT02772003'],
#  'Dawood Sayed, MD': ['NCT06651138'],
#  'Thet Lynn, MD, MMedSc Global Health': ['NCT06650956'],
#  'Vanphanom Sychareun, MD, PhD': ['NCT06650956'],
#  'Shivaani Kummar, MD': ['NCT03345485'],
#  'Ana Oaknin, MD': ['NCT03345485'],
#  'Jacques Izard, PhD': ['NCT04758715'],
#  'Georgi Momekov, Prof PhD': ['NCT05607056'],
#  'Karen Dzhambazov, Prof, PhD': ['NCT05607056'],
#  'Nikolay Sapundziev, Prof, PhD': ['NCT05607056'],
#  'Milena Encheva, MD, PhD': ['NCT05607056'],
#  'Boris Bogov, Prof, PhD': ['NCT05607056'],
#  'Rosen Nikolov, Prof, MD': ['NCT05607056'],
#  'Rumen Benchev, Prof': ['NCT05607056'],
#  'Vladimir Hodzhev, Prof, PhD': ['NCT05607056'],
#  'Spiridon Todorov, Prof, PhD': ['NCT05607056'],
#  'Vania Youroukova, Prof, PhD': ['NCT05607056'],
#  'Surya P Bhatt, MD, MSPH': ['NCT05119556'],
#  'Sivasubramanium Bhavani, MD': ['NCT06253585'],
#  'Cavan Reilly, PhD': ['NCT01056185'],
#  'Michael Goggins, MD': ['NCT02000089'],
#  'Mary Billstrand, MD': ['NCT04928794'],
#  'Ismaël Conejero': ['NCT06650800'],
#  'Ville Sallinen, MD, PhD': ['NCT06650085'],
#  'Marion Rabant, M.D., PhD': ['NCT06650111'],
#  'Ivan Wu': ['NCT05698693'],
#  'Claudia Fox, MD, MPH': ['NCT04007393'],
#  'Kate V Meriwether, MD': ['NCT05309993'],
#  'Zeeshan Afzal, FCPS': ['NCT06650293'],
#  'Aaron Shafer, MD': ['NCT05123807'],
#  'Todd C Lee, MD MPH FIDSA': ['NCT06650488'],
#  'Emily G McDonald, MD MSc': ['NCT06650488'],
#  'Lead Investigator': ['NCT01686607'],
#  'Sarah Prinsloo': ['NCT04650178'],
#  'Elias Jabbour': ['NCT03564678'],
#  'Michael R Harrison, MD': ['NCT02431507'],
#  'David Darrow, MD': ['NCT05741788'],
#  'Abraham Wu, MD': ['NCT02902107'],
#  'Monali Vasekar, MD': ['NCT06504407'],
#  'Massimo Volpe, Professor': ['NCT05279807'],
#  'Charles Powell, DDS, MS': ['NCT06507709'],
#  'Frank A Bucci, Jr., MD': ['NCT04667507'],
#  'Sonja Merten, MD MPH PhD': ['NCT05419687'],
#  'Justin Gregg, MD': ['NCT05454488'],
#  'Rena Jones, Ph.D.': ['NCT00342888'],
#  'David Ostry': ['NCT06467305'],
#  'Nicolas Palaskas, MD': ['NCT06337097'],
#  'Christian Castilla López, MsC': ['NCT06105697'],
#  'Veronkia Bachanova': ['NCT03681561'],
#  'Nancy F Krebs, MD, MS': ['NCT06650397'],
#  'Paul Mulholland': ['NCT06650605'],
#  'Maryam Fouladi, MD': ['NCT05233397', 'NCT05843253'],
#  'Jessica A Reese, PhD': ['NCT06230705'],
#  'Damiano Rondelli, MD': ['NCT02043847'],
#  'Elizabeth McClure, PhD': ['NCT04888377'],
#  'John H Joseph, MD': ['NCT06429033'],
#  'Steven R Grossman, MD': ['NCT06132087'],
#  'Stuart S Winter': ['NCT00408005'],
#  'Michele Staton, MSW, PhD': ['NCT06651528'],
#  'Kevin Knight, PhD': ['NCT06651528'],
#  'Nicola Canessa, PhD': ['NCT04557293'],
#  'Anna GEMAHLING, MD': ['NCT02886611'],
#  'Eric GABISON, MD': ['NCT02886611'],
#  'Dominique BREMOND-GIGNAC, MD': ['NCT02886611'],
#  'Daniel Jones, MBBS, PhD': ['NCT04440761'],
#  'J. Sven D. Mieog, MD PhD': ['NCT05784311'],
#  'Aung Naing, Md': ['NCT06651593'],
#  'Giorgia Sulis, PhD': ['NCT06234683'],
#  'Crystal D Karakochuk, PhD': ['NCT06641245'],
#  'Kelsey M Cochrane, PhD': ['NCT06641245'],
#  'Suzanne Wolden, MD': ['NCT02245997'],
#  'Elizabeth Brem, MD': ['NCT04512105'],
#  'Giorgio Gastaldi, MD, DDS': ['NCT06561945'],
#  'Ugur T. Sener, MD': ['NCT06625047'],
#  'Alain SAAD, MD': ['NCT05072977'],
#  'Rodabe N. Amaria, MD': ['NCT00338377'],
#  'CORALIE NOEL': ['NCT06616753'],
#  'T. John Winhusen, PhD.': ['NCT06651177'],
#  'Lakshmi Koyyalagunta': ['NCT03888651'],
#  'Andrew Kneebone': ['NCT06650033'],
#  'Alethea Desrosiers': ['NCT06651554'],
#  'Jing Sun, MD, Ph.D': ['NCT06063954'],
#  'Sarah Yip, PhD, MSc': ['NCT06651333'],
#  'Claudia Campbell, PhD': ['NCT03150433'],
#  'Trevor Duffy': ['NCT04449354']}

# %%
results_dict = extract_info(final_collection, "principalInvestigator.name", "trialId")
store_in_collection(
    "principalInvestigator.name", "conducted_trial", results_dict, final_collection
)
